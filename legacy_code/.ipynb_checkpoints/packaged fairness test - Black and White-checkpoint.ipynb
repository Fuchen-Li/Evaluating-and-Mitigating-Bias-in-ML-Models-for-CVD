# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from os import path
from sklearn.metrics import balanced_accuracy_score
import sklearn.preprocessing
from sklearn import preprocessing
from sklearn.preprocessing import Normalizer
import src.lib.utility_classfier as uclf
import src.lib.optimal_threhold_related as thres
import src.lib.fairness_tests as fair

# %%
data_path='/Users/lifuchen/Desktop/research/data.csv'
df = pd.read_csv(data_path)

# %%
y = df.Class.values
X = df.drop(['GRID','Class'], axis=1)
X.shape
# Out:
# (109490, 87)

# %%
def balance_accuracy (y_val, y_val_score,y_test, y_test_score):
    uclf.compute_roc(y_val,y_val_score,'decision tree')
    threshold, _ = thres.get_optimal_threshold_Jvalue (y_val, y_val_score)
    print ("Optimal threshold by J value is ",threshold)

    ba_val = thres.calculate_balanced_accuracy(y_val, y_val_score, threshold)
    print ("Balanced accuracy score of val is ", ba_val)

    uclf.compute_roc(y_test,y_test_score,'decision tree')
    ba_test = thres.calculate_balanced_accuracy(y_test, y_test_score, threshold)
    print ("Balanced accuracy score of test is ",ba_test)

    return threshold, ba_val, ba_test

# %%
def fairness_metrics (X, y, attribute, classifier, random_state):
    global threshold
    X_train, y_train, X_val, y_val, X_test, y_test, X_val_white, X_val_black, y_val_white, y_val_black, X_test_white, X_test_black, y_test_white, y_test_black \
        = fair.split_by_trait(X, y, attribute, random_state)
    print("X train", X_train.shape[0])
    print("Y train", y_train.shape[0])
    print(X_val.shape[0], X_val_white.shape[0], X_val_black.shape[0])
    print(y_val.shape[0], y_val_white.shape[0], y_val_black.shape[0])
    print(X_test.shape[0], X_test_white.shape[0], X_test_black.shape[0])
    print(y_test.shape[0], y_test_white.shape[0], y_test_black.shape[0])

    max_abs_scaler = preprocessing.MaxAbsScaler()
    X_train_scaled = max_abs_scaler.fit_transform(X_train)
    X_test_scaled = max_abs_scaler.transform(X_test)
    X_test_white_scaled = max_abs_scaler.transform(X_test_white)
    X_test_black_scaled = max_abs_scaler.transform(X_test_black)
    X_val_scaled = max_abs_scaler.transform(X_val)
    X_val_white_scaled = max_abs_scaler.transform(X_val_white)
    X_val_black_scaled = max_abs_scaler.transform(X_val_black)

    def get_result (classifier, record):
        function_name = "uclf." + classifier
        y_val_score = eval(function_name + "(X_train_scaled, y_train,X_val_scaled, y_val)")
        y_test_score = eval(function_name + "(X_train_scaled, y_train,X_val_scaled, y_val)")
        threshold, ba_val, ba_test = balance_accuracy (y_val, y_val_score,y_test, y_test_score)

        y_val_score_white = eval(function_name + "(X_train_scaled, y_train, X_val_white_scaled, y_val_white)")
        y_test_score_white = eval(function_name + "(X_train_scaled, y_train,X_test_white_scaled, y_test_white)")
        threshold_white, ba_val_white, ba_test_white = balance_accuracy (y_val_white, y_val_score_white,y_test_white, y_test_score_white)

        y_val_score_black = eval(function_name + "(X_train_scaled, y_train, X_val_black_scaled, y_val_black)")
        y_test_score_black = eval(function_name + "(X_train_scaled, y_train,X_test_black_scaled, y_test_black)")
        threshold_black, ba_val_black, ba_test_black = balance_accuracy (y_val_black, y_val_score_black, y_test_black, y_test_score_black)

        eod = fair.get_EOD(y_test_white, y_test_score_white,threshold_white, y_test_black, y_test_score_black, threshold_black)
        sp = fair.get_SP(y_test_white, y_test_score_white,threshold_white, y_test_black, y_test_score_black, threshold_black)

    if classifier == "decision tree":
        y_val_score = uclf.$classifier(X_train_scaled, y_train,X_val_scaled, y_val)
        y_test_score = uclf.decision_tree(X_train_scaled, y_train,X_test_scaled, y_test)
        threshold, ba_val, ba_test = balance_accuracy (y_val, y_val_score,y_test, y_test_score)

        y_val_score_white = uclf.decision_tree(X_train_scaled, y_train, X_val_white_scaled, y_val_white)
        y_test_score_white = uclf.decision_tree(X_train_scaled, y_train,X_test_white_scaled, y_test_white)
        threshold_white, ba_val_white, ba_test_white = balance_accuracy (y_val_white, y_val_score_white,y_test_white, y_test_score_white)

        y_val_score_black = uclf.decision_tree(X_train_scaled, y_train, X_val_black_scaled, y_val_black)
        y_test_score_black = uclf.decision_tree(X_train_scaled, y_train,X_test_black_scaled, y_test_black)
        threshold_black, ba_val_black, ba_test_black = balance_accuracy (y_val_black, y_val_score_black, y_test_black, y_test_score_black)

        eod = fair.get_EOD(y_test_white, y_test_score_white,threshold_white, y_test_black, y_test_score_black, threshold_black)
        sp = fair.get_SP(y_test_white, y_test_score_white,threshold_white, y_test_black, y_test_score_black, threshold_black)

    elif classifier == "logistic regression":
        y_val_score = uclf.logic_regression(X_train_scaled, y_train,X_val_scaled, y_val)
        y_test_score = uclf.logic_regression(X_train_scaled, y_train,X_test_scaled, y_test)
        threshold, ba_val, ba_test = balance_accuracy (y_val, y_val_score,y_test, y_test_score)

        y_val_score_white = uclf.logic_regression(X_train_scaled, y_train, X_val_white_scaled, y_val_white)
        y_test_score_white = uclf.logic_regression(X_train_scaled, y_train,X_test_white_scaled, y_test_white)
        threshold_white, ba_val_white, ba_test_white = balance_accuracy (y_val_white, y_val_score_white,y_test_white, y_test_score_white)

        y_val_score_black = uclf.logic_regression(X_train_scaled, y_train, X_val_black_scaled, y_val_black)
        y_test_score_black = uclf.logic_regression(X_train_scaled, y_train,X_test_black_scaled, y_test_black)
        threshold_black, ba_val_black, ba_test_black = balance_accuracy (y_val_black, y_val_score_black, y_test_black, y_test_score_black)

        eod = fair.get_EOD(y_test_white, y_test_score_white,threshold_white, y_test_black, y_test_score_black, threshold_black)
        sp = fair.get_SP(y_test_white, y_test_score_white,threshold_white, y_test_black, y_test_score_black, threshold_black)

    elif classifier == "logistic regression":
        y_val_score = uclf.decision_tree(X_train_scaled, y_train,X_val_scaled, y_val)
        y_test_score = uclf.decision_tree(X_train_scaled, y_train,X_test_scaled, y_test)
        threshold, ba_val, ba_test = balance_accuracy (y_val, y_val_score,y_test, y_test_score)

        y_val_score_white = uclf.decision_tree(X_train_scaled, y_train, X_val_white_scaled, y_val_white)
        y_test_score_white = uclf.decision_tree(X_train_scaled, y_train,X_test_white_scaled, y_test_white)
        threshold_white, ba_val_white, ba_test_white = balance_accuracy (y_val_white, y_val_score_white,y_test_white, y_test_score_white)

        y_val_score_black = uclf.decision_tree(X_train_scaled, y_train, X_val_black_scaled, y_val_black)
        y_test_score_black = uclf.decision_tree(X_train_scaled, y_train,X_test_black_scaled, y_test_black)
        threshold_black, ba_val_black, ba_test_black = balance_accuracy (y_val_black, y_val_score_black, y_test_black, y_test_score_black)

        eod = fair.get_EOD(y_test_white, y_test_score_white,threshold_white, y_test_black, y_test_score_black, threshold_black)
        sp = fair.get_SP(y_test_white, y_test_score_white,threshold_white, y_test_black, y_test_score_black, threshold_black)

    # noinspection PyUnboundLocalVariable
    records.append({
            'overall threshold': threshold,
            'overall ba validation': ba_val,
            'overall ba test': ba_test,
            'white threshold': threshold_white,
            'white ba validation': ba_val_white,
            'white ba test': ba_test_white,
            'black threshold': threshold_black,
            'black ba validation': ba_val_black,
            'black ba test': ba_test_black,
            'eod': eod,
            'di': sp,
        })

# %%
records = []
for random_state in range(1,16):
    fairness_metrics (X, y, "Race_W", random_state)

result_table = pd.DataFrame(records)
result_path='/Users/lifuchen/Desktop/research/'
result_table.to_csv(path.join(result_path,'detailed-{}result.csv'), index=False)
# Out:
# X train 65694
# Y train 65694
# 21898 18825 3073
# 21898 18825 3073
# 21898 18883 3015
# 21898 18883 3015
# 0.26732574897465733
# 0.2685985620764942
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19980
#            1       0.40      0.00      0.00      1918
#
#     accuracy                           0.91     21898
#    macro avg       0.66      0.50      0.48     21898
# weighted avg       0.87      0.91      0.87     21898
#
# Confusion_matrix
# [[19977     3]
#  [ 1916     2]]
# done in 0.544222s
# 0.26732574897465733
# 0.26985788626648854
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19972
#            1       0.14      0.00      0.00      1926
#
#     accuracy                           0.91     21898
#    macro avg       0.53      0.50      0.48     21898
# weighted avg       0.84      0.91      0.87     21898
# ...

# %%
print ('overall ba validation: %.4f (+/- %.4f)' % (result_table["overall ba validation"].mean(), result_table["overall ba validation"].std()))
print ('overall ba test: %.4f (+/- %.4f)' % (result_table["overall ba test"].mean(), result_table["overall ba test"].std()))
print ('white ba validation: %.4f (+/- %.4f)' % (result_table["white ba validation"].mean(), result_table["white ba validation"].std()))
print ('white ba test: %.4f (+/- %.4f)' % (result_table["white ba test"].mean(), result_table["white ba test"].std()))
print ('black ba validation: %.4f (+/- %.4f)' % (result_table["black ba validation"].mean(), result_table["black ba validation"].std()))
print ('black ba test: %.4f (+/- %.4f)' % (result_table["black ba test"].mean(), result_table["black ba test"].std()))
print ('eod: %.4f (+/- %.4f)' % (result_table["eod"].mean(), result_table["eod"].std()))
print ('di: %.4f (+/- %.4f)' % (result_table["di"].mean(), result_table["di"].std()))
# Out:
# overall ba validation: 0.6794 (+/- 0.0055)
# overall ba test: 0.6803 (+/- 0.0058)
# white ba validation: 0.6785 (+/- 0.0066)
# white ba test: 0.6790 (+/- 0.0062)
# black ba validation: 0.6843 (+/- 0.0123)
# black ba test: 0.6879 (+/- 0.0123)
# eod: 0.0398 (+/- 0.0355)
# di: 1.1931 (+/- 0.0745)

# %%
y_score_rf = uclf.random_forest(X_train_scaled, y_train,X_test_scaled, y_test)
uclf.compute_roc(y_test,y_score_rf,'random_forest')


y_score_gb = uclf.gradiant_boosting(X_train_scaled, y_train,X_test_scaled, y_test)
uclf.compute_roc(y_test,y_score_gb,'gradiant_boosting')
# Out:
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19953
#            1       0.39      0.02      0.03      1945
#
#     accuracy                           0.91     21898
#    macro avg       0.65      0.51      0.49     21898
# weighted avg       0.87      0.91      0.87     21898
#
# Confusion_matrix
# [[19906    47]
#  [ 1915    30]]
# done in 39.468308s

# %%
y_score_dt_white = uclf.decision_tree(X_train_scaled, y_train, X_test_white_scaled, y_test_white)
# Out:
# 0.2662970663670978
# 0.2675000238115467
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     17216
#            1       0.19      0.00      0.01      1691
#
#     accuracy                           0.91     18907
#    macro avg       0.55      0.50      0.48     18907
# weighted avg       0.85      0.91      0.87     18907
#
# Confusion_matrix
# [[17191    25]
#  [ 1685     6]]
# done in 1.019925s

# %%
uclf.compute_roc(y_test_white,y_score_dt_white,'decision tree')

# %%
y_score_dt_black = uclf.decision_tree(X_train_scaled, y_train, X_test_black_scaled, y_test_black)
# Out:
# 0.2662970663670978
# 0.2567660863847162
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      2737
#            1       0.00      0.00      0.00       254
#
#     accuracy                           0.91      2991
#    macro avg       0.46      0.50      0.48      2991
# weighted avg       0.84      0.91      0.87      2991
#
# Confusion_matrix
# [[2730    7]
#  [ 254    0]]
# done in 0.776529s

# %%
uclf.compute_roc(y_test_black,y_score_dt_black,'decision tree')

# %%
eod_dt = fair.get_EOD(y_test_white, y_score_dt_white,y_test_black, y_score_dt_black)
eod_dt
# Out:
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.37000000000000005
# threshold:0.2, J-value:0.169
# threshold:0.30000000000000004, J-value:0.099
# threshold:0.4, J-value:0.002
# threshold:0.5, J-value:0.003
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# True positive rate of class 1 is  0.684
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.38
# threshold:0.2, J-value:0.168
# threshold:0.30000000000000004, J-value:0.07699999999999999
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:-0.003
# threshold:0.6000000000000001, J-value:-0.001
# threshold:0.7000000000000001, J-value:-0.001
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# True positive rate of class 2 is  0.642
# 0.04200000000000004

# %%
sp_dt = fair.get_SP(y_test_white, y_score_dt_white,y_test_black, y_score_dt_black)
sp_dt
# Out:
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.37000000000000005
# threshold:0.2, J-value:0.169
# threshold:0.30000000000000004, J-value:0.099
# threshold:0.4, J-value:0.002
# threshold:0.5, J-value:0.003
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Positive prediction rate of class 1 is  0.347
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.38
# threshold:0.2, J-value:0.168
# threshold:0.30000000000000004, J-value:0.07699999999999999
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:-0.003
# threshold:0.6000000000000001, J-value:-0.001
# threshold:0.7000000000000001, J-value:-0.001
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Positive prediction rate of class 2 is  0.294
# 1.1802721088435375

# %%
y_score_rf_white = uclf.random_forest(X_train_scaled, y_train, X_test_white_scaled, y_test_white)

# %%
uclf.compute_roc(y_test_white,y_score_rf_white,'random forest')

# %%
y_score_rf_black = uclf.random_forest(X_train_scaled, y_train, X_test_black_scaled, y_test_black)

# %%
uclf.compute_roc(y_test_black,y_score_rf_black,'random forest')

# %%
eod_rf = fair.get_EOD(y_test_white, y_score_rf_white,y_test_black, y_score_rf_black)
eod_rf

# %%
sp_rf = fair.get_SP(y_test_white, y_score_rf_white,y_test_black, y_score_rf_black)
sp_rf

# %%
y_score_gb = uclf.gradiant_boosting(X_train_scaled, y_train,X_test_scaled, y_test)

# %%
uclf.compute_roc(y_test,y_score_gb,'gradient boosting')

# %%
y_score_gb_white = uclf.gradiant_boosting(X_train_scaled, y_train, X_test_white_scaled, y_test_white)

# %%
uclf.compute_roc(y_test_white,y_score_gb_white,'gradient boosting')

# %%
y_score_gb_black = uclf.gradiant_boosting(X_train_scaled, y_train, X_test_black_scaled, y_test_black)

# %%
uclf.compute_roc(y_test_black,y_score_gb_black,'gradient boosting')

# %%
eod_gb = fair.get_EOD(y_test_white, y_score_gb_white,y_test_black, y_score_gb_black)
eod_gb

# %%
sp_gb = fair.get_SP(y_test_white, y_score_gb_white,y_test_black, y_score_gb_black)
sp_gb

# %%
y_score = uclf.logic_regression(X_train_scaled, y_train,X_test_scaled, y_test,10)

# %%
threshold_mixed = thres.get_optimal_threshold_Jvalue(y_test, y_score)
threshold_mixed

# %%
tpr_mixed = thres.calculate_tpr(y_test, y_score, threshold=0.1)
tpr_mixed

# %%
pd_mixed = thres.calculate_positive_prediction(y_test, y_score, threshold=0.1)
pd_mixed

# %%
uclf.compute_roc(y_test,y_score,'logistics')

# %%
uclf.plot_prc(y_test,y_score,pos_ratio)

# %%
y_score_white = uclf.logic_regression(X_train_scaled, y_train,X_test_white_scaled, y_test_white,10)

# %%
threshold_white = thres.get_optimal_threshold_Jvalue(y_test_white, y_score_white)
threshold_white

# %%
tpr_white = thres.calculate_tpr(y_test_white, y_score_white, threshold=0.1)
tpr_white

# %%
pd_white = thres.calculate_positive_prediction(y_test_white, y_score_white, threshold=0.1)
pd_white

# %%
y_score_black = uclf.logic_regression(X_train_scaled, y_train,X_test_black_scaled, y_test_black,10)

# %%
threshold_black = thres.get_optimal_threshold_Jvalue(y_test_black, y_score_black)
threshold_black

# %%
tpr_black = thres.calculate_tpr(y_test_black, y_score_black, threshold=0.1)
tpr_black

# %%
pd_black = thres.calculate_positive_prediction(y_test_black, y_score_black, threshold=0.1)
pd_black

# %%
eod = fair.get_EOD(y_test_white, y_score_white,y_test_black, y_score_black)
eod

# %%
sp = fair.get_SP(y_test_white, y_score_white,y_test_black, y_score_black)
sp

# %%
uclf.compute_roc(y_test_white,y_score_white,'logistics')

# %%
uclf.plot_prc(y_test_white,y_score_white,pos_ratio)

# %%
uclf.compute_roc(y_test_black,y_score_black,'logistics')

# %%
uclf.plot_prc(y_test_black,y_score_black,pos_ratio)
