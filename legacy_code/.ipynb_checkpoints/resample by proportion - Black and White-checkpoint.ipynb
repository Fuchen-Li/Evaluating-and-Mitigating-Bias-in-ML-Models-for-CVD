# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from os import path
import imblearn
from imblearn.over_sampling import RandomOverSampler, SMOTE
from sklearn.metrics import balanced_accuracy_score, roc_auc_score
import sklearn.preprocessing
from sklearn import preprocessing
from sklearn.preprocessing import Normalizer
import src.lib.utility_classfier as uclf
import src.lib.optimal_threhold_related as thres
import src.lib.fairness_tests as fair

# %%
data_path='/Users/lifuchen/Desktop/research/data.csv'
df = pd.read_csv(data_path)

# %%
y = df.Class.values
X = df.drop(['GRID','Class'], axis=1)
X.shape
# Out:
# (109490, 87)

# %%
def get_result (classifier, records, X_train_scaled, y_train, X_val_scaled, y_val, X_test_scaled, y_test, X_val_white_scaled, y_val_white, X_test_white_scaled, y_test_white, X_val_black_scaled, y_val_black, X_test_black_scaled, y_test_black):
        method_to_call = getattr(uclf, classifier)
        y_val_score = method_to_call(X_train_scaled, y_train,X_val_scaled, y_val)
        y_test_score = method_to_call(X_train_scaled, y_train,X_test_scaled, y_test)
        
        threshold, ba_val, ba_test = balance_accuracy (y_val, y_val_score,y_test, y_test_score)
        auroc = roc_auc_score(y_val, y_val_score)
        
        y_val_score_white = method_to_call(X_train_scaled, y_train, X_val_white_scaled, y_val_white)
        y_test_score_white = method_to_call(X_train_scaled, y_train,X_test_white_scaled, y_test_white)
        threshold_white, ba_val_white, ba_test_white = balance_accuracy (y_val_white, y_val_score_white,y_test_white, y_test_score_white)

        y_val_score_black = method_to_call(X_train_scaled, y_train, X_val_black_scaled, y_val_black)
        y_test_score_black = method_to_call(X_train_scaled, y_train,X_test_black_scaled, y_test_black)
        threshold_black, ba_val_black, ba_test_black = balance_accuracy (y_val_black, y_val_score_black, y_test_black, y_test_score_black)

        eod = fair.get_EOD(y_test_white, y_test_score_white,threshold_white, y_test_black, y_test_score_black, threshold_black)
        sp = fair.get_SP(y_test_white, y_test_score_white,threshold_white, y_test_black, y_test_score_black, threshold_black)

        records.append({
            'auroc': auroc,
            'overall threshold': threshold,
            'overall ba validation': ba_val,
            'overall ba test': ba_test,
            'white threshold': threshold_white,
            'white ba validation': ba_val_white,
            'white ba test': ba_test_white,
            'black threshold': threshold_black,
            'black ba validation': ba_val_black,
            'black ba test': ba_test_black,
            'eod': eod,
            'di': sp,
        })

# %%
def balance_accuracy (y_val, y_val_score,y_test, y_test_score):
    
    threshold, _ = thres.get_optimal_threshold_Jvalue (y_val, y_val_score)
    print ("Optimal threshold by J value is ",threshold)

    ba_val = thres.calculate_balanced_accuracy(y_val, y_val_score, threshold)
    print ("Balanced accuracy score of val is ", ba_val)

    ba_test = thres.calculate_balanced_accuracy(y_test, y_test_score, threshold)
    print ("Balanced accuracy score of test is ",ba_test)

    return threshold, ba_val, ba_test

# %%
def fairness_metrics (X, y, attribute, random_state):
    global threshold
    X_train, y_train, X_val, y_val, X_test, y_test, X_val_white, X_val_black, y_val_white, y_val_black, X_test_white, X_test_black, y_test_white, y_test_black \
        = fair.split_by_trait_balance_size(X, y, attribute, random_state)
    
    print("X train", X_train.shape[0])
    print("Y train", y_train.shape[0])
    print(X_val.shape[0], X_val_white.shape[0], X_val_black.shape[0])
    print(y_val.shape[0], y_val_white.shape[0], y_val_black.shape[0])
    print(X_test.shape[0], X_test_white.shape[0], X_test_black.shape[0])
    print(y_test.shape[0], y_test_white.shape[0], y_test_black.shape[0])

    max_abs_scaler = preprocessing.MaxAbsScaler()
    X_train_scaled = max_abs_scaler.fit_transform(X_train)
    X_test_scaled = max_abs_scaler.transform(X_test)
    X_test_white_scaled = max_abs_scaler.transform(X_test_white)
    X_test_black_scaled = max_abs_scaler.transform(X_test_black)
    X_val_scaled = max_abs_scaler.transform(X_val)
    X_val_white_scaled = max_abs_scaler.transform(X_val_white)
    X_val_black_scaled = max_abs_scaler.transform(X_val_black)

    get_result ("logic_regression", records_lr, X_train_scaled, y_train, X_val_scaled, y_val, X_test_scaled, y_test, X_val_white_scaled, y_val_white, X_test_white_scaled, y_test_white, X_val_black_scaled, y_val_black, X_test_black_scaled, y_test_black)
    get_result ("random_forest", records_rf, X_train_scaled, y_train, X_val_scaled, y_val, X_test_scaled, y_test, X_val_white_scaled, y_val_white, X_test_white_scaled, y_test_white, X_val_black_scaled, y_val_black, X_test_black_scaled, y_test_black)
    get_result ("decision_tree", records_dt, X_train_scaled, y_train, X_val_scaled, y_val, X_test_scaled, y_test, X_val_white_scaled, y_val_white, X_test_white_scaled, y_test_white, X_val_black_scaled, y_val_black, X_test_black_scaled, y_test_black)
    get_result ("gradiant_boosting", records_gbt, X_train_scaled, y_train, X_val_scaled, y_val, X_test_scaled, y_test, X_val_white_scaled, y_val_white, X_test_white_scaled, y_test_white, X_val_black_scaled, y_val_black, X_test_black_scaled, y_test_black)

# %%
records_lr = []
records_rf = []
records_dt = []
records_gbt = []
for random_state in range(0,4):
    fairness_metrics (X, y, "Race_W", random_state)

result_lr = pd.DataFrame(records_lr)
result_rf = pd.DataFrame(records_rf)
result_dt = pd.DataFrame(records_dt)
result_gbt = pd.DataFrame(records_gbt)
# Out:
# /Users/lifuchen/Desktop/research/CVDPrediction-master/src/lib/fairness_tests.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train ['Class'] = y_train
# (56639,)
# (56639,)
# (113278, 87)
# X train 113278
# Y train 113278
# 21898 18899 2999
# 21898 18899 2999
# 21898 18968 2930
# 21898 18968 2930
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.1745291292673417
# 0.266569928409999
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95     19904
#            1       0.45      0.05      0.08      1994
#
#     accuracy                           0.91     21898
#    macro avg       0.68      0.52      0.52     21898
# weighted avg       0.87      0.91      0.87     21898
#
# Confusion_matrix
# [[19793   111]
#  [ 1904    90]]
# done in 0.847969s
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.1745291292673417
# 0.26554223404242555
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95     19934
#            1       0.41      0.05      0.08      1964
#
#     accuracy                           0.91     21898
#    macro avg       0.66      0.52      0.52     21898
# weighted avg       0.87      0.91      0.87     21898
#
# Confusion_matrix
# [[19808   126]
#  [ 1875    89]]
# done in 0.802813s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.39
# threshold:0.2, J-value:0.241
# threshold:0.30000000000000004, J-value:0.152
# threshold:0.4, J-value:0.082
# threshold:0.5, J-value:0.039
# threshold:0.6000000000000001, J-value:0.016
# threshold:0.7000000000000001, J-value:0.006
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6947815915592437
# Balanced accuracy score of test is  0.6894222165324798
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.1745291292673417
# 0.263776487871698
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95     17180
#            1       0.45      0.05      0.09      1719
#
#     accuracy                           0.91     18899
#    macro avg       0.68      0.52      0.52     18899
# weighted avg       0.87      0.91      0.87     18899
#
# Confusion_matrix
# [[17073   107]
#  [ 1631    88]]
# done in 0.895574s
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.1745291292673417
# 0.2633775057741107
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95     17260
#            1       0.41      0.05      0.09      1708
#
#     accuracy                           0.91     18968
#    macro avg       0.66      0.52      0.52     18968
# weighted avg       0.87      0.91      0.87     18968
#
# Confusion_matrix
# [[17136   124]
#  [ 1622    86]]
# done in 0.793188s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.404
# threshold:0.2, J-value:0.26
# threshold:0.30000000000000004, J-value:0.16699999999999998
# threshold:0.4, J-value:0.093
# threshold:0.5, J-value:0.045
# threshold:0.6000000000000001, J-value:0.019000000000000003
# threshold:0.7000000000000001, J-value:0.007
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7019928099356572
# Balanced accuracy score of test is  0.695846144243842
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.1745291292673417
# 0.28417354052515437
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      2724
#            1       0.33      0.01      0.01       275
#
#     accuracy                           0.91      2999
#    macro avg       0.62      0.50      0.48      2999
# weighted avg       0.86      0.91      0.87      2999
#
# Confusion_matrix
# [[2720    4]
#  [ 273    2]]
# done in 0.878246s
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.1745291292673417
# 0.2795560790231069
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      2674
#            1       0.60      0.01      0.02       256
#
#     accuracy                           0.91      2930
#    macro avg       0.76      0.51      0.49      2930
# weighted avg       0.89      0.91      0.87      2930
#
# Confusion_matrix
# [[2672    2]
#  [ 253    3]]
# done in 0.826548s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.301
# threshold:0.2, J-value:0.12399999999999999
# threshold:0.30000000000000004, J-value:0.055
# threshold:0.4, J-value:0.022000000000000002
# threshold:0.5, J-value:0.006
# threshold:0.6000000000000001, J-value:-0.001
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6503610999866507
# Balanced accuracy score of test is  0.6442858311518325
# True positive rate of class 1 is  0.642
# True positive rate of class 2 is  0.383
# Positive prediction rate of class 1 is  0.286
# Positive prediction rate of class 2 is  0.119
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19904
#            1       0.56      0.00      0.00      1994
#
#     accuracy                           0.91     21898
#    macro avg       0.73      0.50      0.48     21898
# weighted avg       0.88      0.91      0.87     21898
#
# Confusion_matrix
# [[19900     4]
#  [ 1989     5]]
# done in 38.410761s
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19934
#            1       0.36      0.00      0.00      1964
#
#     accuracy                           0.91     21898
#    macro avg       0.64      0.50      0.48     21898
# weighted avg       0.86      0.91      0.87     21898
#
# Confusion_matrix
# [[19927     7]
#  [ 1960     4]]
# done in 38.719179s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.407
# threshold:0.2, J-value:0.267
# threshold:0.30000000000000004, J-value:0.091
# threshold:0.4, J-value:0.021
# threshold:0.5, J-value:0.003
# threshold:0.6000000000000001, J-value:0.001
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7034932419847968
# Balanced accuracy score of test is  0.6885528506801569
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     17180
#            1       0.47      0.00      0.01      1719
#
#     accuracy                           0.91     18899
#    macro avg       0.69      0.50      0.48     18899
# weighted avg       0.87      0.91      0.87     18899
#
# Confusion_matrix
# [[17172     8]
#  [ 1712     7]]
# done in 38.049142s
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     17260
#            1       0.50      0.00      0.01      1708
#
#     accuracy                           0.91     18968
#    macro avg       0.71      0.50      0.48     18968
# weighted avg       0.87      0.91      0.87     18968
#
# Confusion_matrix
# [[17253     7]
#  [ 1701     7]]
# done in 40.119302s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.39499999999999996
# threshold:0.2, J-value:0.272
# threshold:0.30000000000000004, J-value:0.10500000000000001
# threshold:0.4, J-value:0.022000000000000002
# threshold:0.5, J-value:0.004
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.697690199448606
# Balanced accuracy score of test is  0.6844542484280911
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      2724
#            1       0.00      0.00      0.00       275
#
#     accuracy                           0.91      2999
#    macro avg       0.45      0.50      0.48      2999
# weighted avg       0.83      0.91      0.86      2999
#
# Confusion_matrix
# [[2724    0]
#  [ 275    0]]
# done in 38.725323s
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      2674
#            1       0.00      0.00      0.00       256
#
#     accuracy                           0.91      2930
#    macro avg       0.46      0.50      0.48      2930
# weighted avg       0.83      0.91      0.87      2930
#
# Confusion_matrix
# [[2674    0]
#  [ 256    0]]
# done in 37.520637s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.405
# threshold:0.2, J-value:0.21000000000000002
# threshold:0.30000000000000004, J-value:0.061000000000000006
# threshold:0.4, J-value:-0.001
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7024909891870244
# Balanced accuracy score of test is  0.68387422868362
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# True positive rate of class 1 is  0.713
# True positive rate of class 2 is  0.617
# Positive prediction rate of class 1 is  0.377
# Positive prediction rate of class 2 is  0.282
# 0.17930149121056152
# 0.27906950849927226
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19904
#            1       0.25      0.00      0.01      1994
#
#     accuracy                           0.91     21898
#    macro avg       0.58      0.50      0.48     21898
# weighted avg       0.85      0.91      0.87     21898
#
# Confusion_matrix
# [[19877    27]
#  [ 1985     9]]
# done in 1.381484s
# 0.17930149121056152
# 0.27642847879951965
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19934
#            1       0.14      0.00      0.00      1964
#
#     accuracy                           0.91     21898
#    macro avg       0.53      0.50      0.48     21898
# weighted avg       0.84      0.91      0.87     21898
#
# Confusion_matrix
# [[19916    18]
#  [ 1961     3]]
# done in 1.322003s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.34299999999999997
# threshold:0.2, J-value:0.18
# threshold:0.30000000000000004, J-value:0.064
# threshold:0.4, J-value:0.004
# threshold:0.5, J-value:0.004
# threshold:0.6000000000000001, J-value:0.001
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6716962331931486
# Balanced accuracy score of test is  0.6652813245012001
# 0.17930149121056152
# 0.2742897973799019
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     17180
#            1       0.25      0.00      0.01      1719
#
#     accuracy                           0.91     18899
#    macro avg       0.58      0.50      0.48     18899
# weighted avg       0.85      0.91      0.87     18899
#
# Confusion_matrix
# [[17165    15]
#  [ 1714     5]]
# done in 1.337557s
# 0.17930149121056152
# 0.27289427398322447
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     17260
#            1       0.12      0.00      0.00      1708
#
#     accuracy                           0.91     18968
#    macro avg       0.52      0.50      0.48     18968
# weighted avg       0.84      0.91      0.87     18968
#
# Confusion_matrix
# [[17246    14]
#  [ 1706     2]]
# done in 1.316595s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.36000000000000004
# threshold:0.2, J-value:0.19599999999999998
# threshold:0.30000000000000004, J-value:0.063
# threshold:0.4, J-value:0.002
# threshold:0.5, J-value:0.002
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6797860791631705
# Balanced accuracy score of test is  0.6722549599594031
# 0.17930149121056152
# 0.3091901355232737
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      2724
#            1       0.25      0.01      0.03       275
#
#     accuracy                           0.91      2999
#    macro avg       0.58      0.51      0.49      2999
# weighted avg       0.85      0.91      0.87      2999
#
# Confusion_matrix
# [[2712   12]
#  [ 271    4]]
# done in 1.350638s
# 0.17930149121056152
# 0.2993079316853516
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      2674
#            1       0.20      0.00      0.01       256
#
#     accuracy                           0.91      2930
#    macro avg       0.56      0.50      0.48      2930
# weighted avg       0.85      0.91      0.87      2930
#
# Confusion_matrix
# [[2670    4]
#  [ 255    1]]
# done in 1.290574s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.244
# threshold:0.2, J-value:0.086
# threshold:0.30000000000000004, J-value:0.066
# threshold:0.4, J-value:0.011
# threshold:0.5, J-value:0.011
# threshold:0.6000000000000001, J-value:0.004
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6218135095447871
# Balanced accuracy score of test is  0.6160495161742707
# True positive rate of class 1 is  0.646
# True positive rate of class 2 is  0.348
# Positive prediction rate of class 1 is  0.332
# Positive prediction rate of class 2 is  0.136
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19904
#            1       0.47      0.03      0.06      1994
#
#     accuracy                           0.91     21898
#    macro avg       0.69      0.51      0.51     21898
# weighted avg       0.87      0.91      0.87     21898
#
# Confusion_matrix
# [[19831    73]
#  [ 1930    64]]
# done in 74.220945s
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19934
#            1       0.44      0.03      0.06      1964
#
#     accuracy                           0.91     21898
#    macro avg       0.68      0.51      0.51     21898
# weighted avg       0.87      0.91      0.87     21898
#
# Confusion_matrix
# [[19854    80]
#  [ 1901    63]]
# done in 74.242783s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.397
# threshold:0.2, J-value:0.256
# threshold:0.30000000000000004, J-value:0.13899999999999998
# threshold:0.4, J-value:0.069
# threshold:0.5, J-value:0.028
# threshold:0.6000000000000001, J-value:0.008
# threshold:0.7000000000000001, J-value:0.001
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6986252164854693
# Balanced accuracy score of test is  0.6949287026004553
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     17180
#            1       0.46      0.03      0.06      1719
#
#     accuracy                           0.91     18899
#    macro avg       0.68      0.51      0.51     18899
# weighted avg       0.87      0.91      0.87     18899
#
# Confusion_matrix
# [[17112    68]
#  [ 1662    57]]
# done in 72.841683s
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     17260
#            1       0.42      0.03      0.06      1708
#
#     accuracy                           0.91     18968
#    macro avg       0.67      0.51      0.51     18968
# weighted avg       0.87      0.91      0.87     18968
#
# Confusion_matrix
# [[17185    75]
#  [ 1653    55]]
# done in 73.529602s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.41100000000000003
# threshold:0.2, J-value:0.271
# threshold:0.30000000000000004, J-value:0.151
# threshold:0.4, J-value:0.074
# threshold:0.5, J-value:0.029
# threshold:0.6000000000000001, J-value:0.007
# threshold:0.7000000000000001, J-value:0.001
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7055358314692801
# Balanced accuracy score of test is  0.6993896217377972
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      2724
#            1       0.58      0.03      0.05       275
#
#     accuracy                           0.91      2999
#    macro avg       0.75      0.51      0.50      2999
# weighted avg       0.88      0.91      0.87      2999
#
# Confusion_matrix
# [[2719    5]
#  [ 268    7]]
# done in 77.054922s
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      2674
#            1       0.62      0.03      0.06       256
#
#     accuracy                           0.91      2930
#    macro avg       0.77      0.51      0.51      2930
# weighted avg       0.89      0.91      0.88      2930
#
# Confusion_matrix
# [[2669    5]
#  [ 248    8]]
# done in 78.049577s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.313
# threshold:0.2, J-value:0.16
# threshold:0.30000000000000004, J-value:0.064
# threshold:0.4, J-value:0.034
# threshold:0.5, J-value:0.023
# threshold:0.6000000000000001, J-value:0.009999999999999998
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6562448271258844
# Balanced accuracy score of test is  0.6614286298616305
# True positive rate of class 1 is  0.666
# True positive rate of class 2 is  0.441
# Positive prediction rate of class 1 is  0.303
# Positive prediction rate of class 2 is  0.147
# /Users/lifuchen/Desktop/research/CVDPrediction-master/src/lib/fairness_tests.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train ['Class'] = y_train
# (56798,)
# (56798,)
# (113596, 87)
# X train 113596
# Y train 113596
# 21898 18825 3073
# 21898 18825 3073
# 21898 18883 3015
# 21898 18883 3015
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.17554712104469375
# 0.2602976043015669
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95     19980
#            1       0.39      0.05      0.08      1918
#
#     accuracy                           0.91     21898
#    macro avg       0.65      0.52      0.52     21898
# weighted avg       0.87      0.91      0.88     21898
#
# Confusion_matrix
# [[19843   137]
#  [ 1830    88]]
# done in 0.917382s
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.17554712104469375
# 0.26133257842196905
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95     19972
#            1       0.47      0.05      0.09      1926
#
#     accuracy                           0.91     21898
#    macro avg       0.69      0.52      0.52     21898
# weighted avg       0.88      0.91      0.88     21898
#
# Confusion_matrix
# [[19860   112]
#  [ 1827    99]]
# done in 0.931157s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.373
# threshold:0.2, J-value:0.26599999999999996
# threshold:0.30000000000000004, J-value:0.163
# threshold:0.4, J-value:0.079
# threshold:0.5, J-value:0.039
# threshold:0.6000000000000001, J-value:0.016
# threshold:0.7000000000000001, J-value:0.007
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.001
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6866846251882748
# Balanced accuracy score of test is  0.6922006489251099
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.17554712104469375
# 0.256188399095871
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95     17178
#            1       0.39      0.05      0.09      1647
#
#     accuracy                           0.91     18825
#    macro avg       0.65      0.52      0.52     18825
# weighted avg       0.87      0.91      0.88     18825
#
# Confusion_matrix
# [[17044   134]
#  [ 1563    84]]
# done in 0.886296s
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.17554712104469375
# 0.26189537331994234
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95     17196
#            1       0.47      0.06      0.10      1687
#
#     accuracy                           0.91     18883
#    macro avg       0.69      0.53      0.53     18883
# weighted avg       0.87      0.91      0.88     18883
#
# Confusion_matrix
# [[17085   111]
#  [ 1590    97]]
# done in 0.853197s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.4
# threshold:0.2, J-value:0.28800000000000003
# threshold:0.30000000000000004, J-value:0.178
# threshold:0.4, J-value:0.088
# threshold:0.5, J-value:0.043
# threshold:0.6000000000000001, J-value:0.018000000000000002
# threshold:0.7000000000000001, J-value:0.008
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.001
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6997937167483042
# Balanced accuracy score of test is  0.6972633625525739
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.17554712104469375
# 0.28547033062672944
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      2802
#            1       0.57      0.01      0.03       271
#
#     accuracy                           0.91      3073
#    macro avg       0.74      0.51      0.49      3073
# weighted avg       0.88      0.91      0.87      3073
#
# Confusion_matrix
# [[2799    3]
#  [ 267    4]]
# done in 0.817512s
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.17554712104469375
# 0.2578077837093885
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      2776
#            1       0.67      0.01      0.02       239
#
#     accuracy                           0.92      3015
#    macro avg       0.79      0.50      0.49      3015
# weighted avg       0.90      0.92      0.88      3015
#
# Confusion_matrix
# [[2775    1]
#  [ 237    2]]
# done in 0.850035s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.21599999999999997
# threshold:0.2, J-value:0.128
# threshold:0.30000000000000004, J-value:0.074
# threshold:0.4, J-value:0.033999999999999996
# threshold:0.5, J-value:0.013999999999999999
# threshold:0.6000000000000001, J-value:0.003
# threshold:0.7000000000000001, J-value:-0.001
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6076873134898373
# Balanced accuracy score of test is  0.6463869931149241
# True positive rate of class 1 is  0.642
# True positive rate of class 2 is  0.372
# Positive prediction rate of class 1 is  0.283
# Positive prediction rate of class 2 is  0.103
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19980
#            1       0.80      0.00      0.00      1918
#
#     accuracy                           0.91     21898
#    macro avg       0.86      0.50      0.48     21898
# weighted avg       0.90      0.91      0.87     21898
#
# Confusion_matrix
# [[19979     1]
#  [ 1914     4]]
# done in 39.314964s
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19972
#            1       0.40      0.00      0.00      1926
#
#     accuracy                           0.91     21898
#    macro avg       0.66      0.50      0.48     21898
# weighted avg       0.87      0.91      0.87     21898
#
# Confusion_matrix
# [[19969     3]
#  [ 1924     2]]
# done in 39.696740s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.38099999999999995
# threshold:0.2, J-value:0.267
# threshold:0.30000000000000004, J-value:0.103
# threshold:0.4, J-value:0.016
# threshold:0.5, J-value:0.002
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6905720110099672
# Balanced accuracy score of test is  0.7011213674221792
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     17178
#            1       0.50      0.00      0.00      1647
#
#     accuracy                           0.91     18825
#    macro avg       0.71      0.50      0.48     18825
# weighted avg       0.88      0.91      0.87     18825
#
# Confusion_matrix
# [[17175     3]
#  [ 1644     3]]
# done in 39.060245s
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     17196
#            1       0.80      0.00      0.00      1687
#
#     accuracy                           0.91     18883
#    macro avg       0.86      0.50      0.48     18883
# weighted avg       0.90      0.91      0.87     18883
#
# Confusion_matrix
# [[17195     1]
#  [ 1683     4]]
# done in 39.302193s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.39199999999999996
# threshold:0.2, J-value:0.28600000000000003
# threshold:0.30000000000000004, J-value:0.10900000000000001
# threshold:0.4, J-value:0.024
# threshold:0.5, J-value:0.002
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6963597803010204
# Balanced accuracy score of test is  0.6952623044219903
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      2802
#            1       0.00      0.00      0.00       271
#
#     accuracy                           0.91      3073
#    macro avg       0.46      0.50      0.48      3073
# weighted avg       0.83      0.91      0.87      3073
#
# Confusion_matrix
# [[2802    0]
#  [ 271    0]]
# done in 38.243077s
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      2776
#            1       0.00      0.00      0.00       239
#
#     accuracy                           0.92      3015
#    macro avg       0.46      0.50      0.48      3015
# weighted avg       0.85      0.92      0.88      3015
#
# Confusion_matrix
# [[2776    0]
#  [ 239    0]]
# done in 38.407535s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.39
# threshold:0.2, J-value:0.20700000000000002
# threshold:0.30000000000000004, J-value:0.05600000000000001
# threshold:0.4, J-value:0.009999999999999998
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6952269201492871
# Balanced accuracy score of test is  0.7029673049328977
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# True positive rate of class 1 is  0.731
# True positive rate of class 2 is  0.632
# Positive prediction rate of class 1 is  0.376
# Positive prediction rate of class 2 is  0.258
# 0.18076069224942903
# 0.27312989204339694
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19980
#            1       0.00      0.00      0.00      1918
#
#     accuracy                           0.91     21898
#    macro avg       0.46      0.50      0.48     21898
# weighted avg       0.83      0.91      0.87     21898
#
# Confusion_matrix
# [[19979     1]
#  [ 1918     0]]
# done in 1.391174s
# 0.18076069224942903
# 0.27070593841040863
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19972
#            1       0.00      0.00      0.00      1926
#
#     accuracy                           0.91     21898
#    macro avg       0.46      0.50      0.48     21898
# weighted avg       0.83      0.91      0.87     21898
#
# Confusion_matrix
# [[19971     1]
#  [ 1926     0]]
# done in 1.383214s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.335
# threshold:0.2, J-value:0.18
# threshold:0.30000000000000004, J-value:0.101
# threshold:0.4, J-value:0.001
# threshold:0.5, J-value:0.001
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6675562423737607
# Balanced accuracy score of test is  0.67819006838026
# 0.18076069224942903
# 0.26589059717531194
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     17178
#            1       0.00      0.00      0.00      1647
#
#     accuracy                           0.91     18825
#    macro avg       0.46      0.50      0.48     18825
# weighted avg       0.83      0.91      0.87     18825
#
# Confusion_matrix
# [[17178     0]
#  [ 1647     0]]
# done in 1.364130s
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.18076069224942903
# 0.26899444403083433
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     17196
#            1       0.00      0.00      0.00      1687
#
#     accuracy                           0.91     18883
#    macro avg       0.46      0.50      0.48     18883
# weighted avg       0.83      0.91      0.87     18883
#
# Confusion_matrix
# [[17196     0]
#  [ 1687     0]]
# done in 1.385925s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.344
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# threshold:0.2, J-value:0.196
# threshold:0.30000000000000004, J-value:0.11400000000000002
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6717951711438424
# Balanced accuracy score of test is  0.6796937102175511
# 0.18076069224942903
# 0.3062534533607046
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      2802
#            1       0.00      0.00      0.00       271
#
#     accuracy                           0.91      3073
#    macro avg       0.46      0.50      0.48      3073
# weighted avg       0.83      0.91      0.87      3073
#
# Confusion_matrix
# [[2802    0]
#  [ 271    0]]
# done in 1.330447s
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.18076069224942903
# 0.2814250589309726
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      2776
#            1       0.00      0.00      0.00       239
#
#     accuracy                           0.92      3015
#    macro avg       0.46      0.50      0.48      3015
# weighted avg       0.85      0.92      0.88      3015
#
# Confusion_matrix
# [[2775    1]
#  [ 239    0]]
# done in 1.348367s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.28500000000000003
# threshold:0.2, J-value:0.08399999999999999
# threshold:0.30000000000000004, J-value:0.027999999999999997
# threshold:0.4, J-value:0.004
# threshold:0.5, J-value:0.004
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6426511374321452
# Balanced accuracy score of test is  0.656499825160069
# True positive rate of class 1 is  0.699
# True positive rate of class 2 is  0.469
# Positive prediction rate of class 1 is  0.372
# Positive prediction rate of class 2 is  0.18
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19980
#            1       0.41      0.03      0.05      1918
#
#     accuracy                           0.91     21898
#    macro avg       0.66      0.51      0.50     21898
# weighted avg       0.87      0.91      0.87     21898
#
# Confusion_matrix
# [[19902    78]
#  [ 1864    54]]
# done in 76.290057s
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19972
#            1       0.44      0.03      0.06      1926
#
#     accuracy                           0.91     21898
#    macro avg       0.68      0.51      0.51     21898
# weighted avg       0.87      0.91      0.88     21898
#
# Confusion_matrix
# [[19892    80]
#  [ 1862    64]]
# done in 77.616789s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.393
# threshold:0.2, J-value:0.261
# threshold:0.30000000000000004, J-value:0.151
# threshold:0.4, J-value:0.07400000000000001
# threshold:0.5, J-value:0.024
# threshold:0.6000000000000001, J-value:0.006
# threshold:0.7000000000000001, J-value:0.003
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6967414494786758
# Balanced accuracy score of test is  0.7020369535002171
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     17178
#            1       0.43      0.03      0.06      1647
#
#     accuracy                           0.91     18825
#    macro avg       0.67      0.51      0.50     18825
# weighted avg       0.87      0.91      0.88     18825
#
# Confusion_matrix
# [[17112    66]
#  [ 1598    49]]
# done in 77.916741s
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     17196
#            1       0.44      0.03      0.06      1687
#
#     accuracy                           0.91     18883
#    macro avg       0.67      0.51      0.51     18883
# weighted avg       0.87      0.91      0.87     18883
#
# Confusion_matrix
# [[17125    71]
#  [ 1632    55]]
# done in 76.796078s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.41999999999999993
# threshold:0.2, J-value:0.28200000000000003
# threshold:0.30000000000000004, J-value:0.163
# threshold:0.4, J-value:0.079
# threshold:0.5, J-value:0.026
# threshold:0.6000000000000001, J-value:0.006
# threshold:0.7000000000000001, J-value:0.003
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7098758186276724
# Balanced accuracy score of test is  0.7065990484822087
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      2802
#            1       0.33      0.02      0.03       271
#
#     accuracy                           0.91      3073
#    macro avg       0.62      0.51      0.49      3073
# weighted avg       0.86      0.91      0.87      3073
#
# Confusion_matrix
# [[2792   10]
#  [ 266    5]]
# done in 76.606268s
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      2776
#            1       0.53      0.04      0.08       239
#
#     accuracy                           0.92      3015
#    macro avg       0.72      0.52      0.52      3015
# weighted avg       0.89      0.92      0.89      3015
#
# Confusion_matrix
# [[2767    9]
#  [ 229   10]]
# done in 75.479774s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.23500000000000001
# threshold:0.2, J-value:0.134
# threshold:0.30000000000000004, J-value:0.081
# threshold:0.4, J-value:0.041
# threshold:0.5, J-value:0.013999999999999999
# threshold:0.6000000000000001, J-value:0.002
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6175754798233207
# Balanced accuracy score of test is  0.6574011551493375
# True positive rate of class 1 is  0.688
# True positive rate of class 2 is  0.414
# Positive prediction rate of class 1 is  0.312
# Positive prediction rate of class 2 is  0.124
# /Users/lifuchen/Desktop/research/CVDPrediction-master/src/lib/fairness_tests.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train ['Class'] = y_train
# (56741,)
# (56741,)
# (113482, 87)
# X train 113482
# Y train 113482
# 21898 18936 2962
# 21898 18936 2962
# 21898 18829 3069
# 21898 18829 3069
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.17560485253966385
# 0.2638883796366986
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19950
#            1       0.46      0.04      0.08      1948
#
#     accuracy                           0.91     21898
#    macro avg       0.69      0.52      0.52     21898
# weighted avg       0.87      0.91      0.88     21898
#
# Confusion_matrix
# [[19851    99]
#  [ 1865    83]]
# done in 0.817653s
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.17560485253966385
# 0.2655876031000081
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19883
#            1       0.44      0.04      0.07      2015
#
#     accuracy                           0.91     21898
#    macro avg       0.68      0.52      0.51     21898
# weighted avg       0.87      0.91      0.87     21898
#
# Confusion_matrix
# [[19786    97]
#  [ 1938    77]]
# done in 0.816254s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.367
# threshold:0.2, J-value:0.239
# threshold:0.30000000000000004, J-value:0.149
# threshold:0.4, J-value:0.082
# threshold:0.5, J-value:0.038
# threshold:0.6000000000000001, J-value:0.015000000000000001
# threshold:0.7000000000000001, J-value:0.005
# threshold:0.8, J-value:0.002
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6835566843185994
# Balanced accuracy score of test is  0.6983375201504484
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.17560485253966385
# 0.2642075118749599
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95     17239
#            1       0.46      0.05      0.09      1697
#
#     accuracy                           0.91     18936
#    macro avg       0.69      0.52      0.52     18936
# weighted avg       0.87      0.91      0.87     18936
#
# Confusion_matrix
# [[17143    96]
#  [ 1616    81]]
# done in 0.813050s
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.17560485253966385
# ...
# threshold:0.4, J-value:0.097
# threshold:0.5, J-value:0.045
# threshold:0.6000000000000001, J-value:0.023
# threshold:0.7000000000000001, J-value:0.007
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.001
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6960911464388126
# Balanced accuracy score of test is  0.7037973667851172
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.17416229161394378
# 0.28386610741145607
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      2704
#            1       0.80      0.02      0.03       262
#
#     accuracy                           0.91      2966
#    macro avg       0.86      0.51      0.49      2966
# weighted avg       0.90      0.91      0.87      2966
#
# Confusion_matrix
# [[2703    1]
#  [ 258    4]]
# done in 0.814017s
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.17416229161394378
# 0.26622066425929786
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      2762
#            1       0.43      0.01      0.02       254
#
#     accuracy                           0.92      3016
#    macro avg       0.67      0.51      0.49      3016
# weighted avg       0.88      0.92      0.88      3016
#
# Confusion_matrix
# [[2758    4]
#  [ 251    3]]
# done in 0.830086s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.267
# threshold:0.2, J-value:0.125
# threshold:0.30000000000000004, J-value:0.07300000000000001
# threshold:0.4, J-value:0.019
# threshold:0.5, J-value:0.015
# threshold:0.6000000000000001, J-value:0.011
# threshold:0.7000000000000001, J-value:0.008
# threshold:0.8, J-value:0.004
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6331615023262117
# Balanced accuracy score of test is  0.6480868023285649
# True positive rate of class 1 is  0.647
# True positive rate of class 2 is  0.374
# Positive prediction rate of class 1 is  0.277
# Positive prediction rate of class 2 is  0.103
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19908
#            1       0.36      0.00      0.00      1990
#
#     accuracy                           0.91     21898
#    macro avg       0.64      0.50      0.48     21898
# weighted avg       0.86      0.91      0.87     21898
#
# Confusion_matrix
# [[19901     7]
#  [ 1986     4]]
# done in 37.960080s
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19918
#            1       0.75      0.00      0.00      1980
#
#     accuracy                           0.91     21898
#    macro avg       0.83      0.50      0.48     21898
# weighted avg       0.90      0.91      0.87     21898
#
# Confusion_matrix
# [[19917     1]
#  [ 1977     3]]
# done in 37.763845s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.38299999999999995
# threshold:0.2, J-value:0.263
# threshold:0.30000000000000004, J-value:0.09999999999999999
# threshold:0.4, J-value:0.024
# threshold:0.5, J-value:0.002
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6911700859127867
# Balanced accuracy score of test is  0.7021313141455726
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     17204
#            1       0.43      0.00      0.00      1728
#
#     accuracy                           0.91     18932
#    macro avg       0.67      0.50      0.48     18932
# weighted avg       0.87      0.91      0.87     18932
#
# Confusion_matrix
# [[17200     4]
#  [ 1725     3]]
# done in 37.783838s
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     17156
#            1       0.38      0.00      0.00      1726
#
#     accuracy                           0.91     18882
#    macro avg       0.64      0.50      0.48     18882
# weighted avg       0.86      0.91      0.87     18882
#
# Confusion_matrix
# [[17151     5]
#  [ 1723     3]]
# done in 37.744609s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.38099999999999995
# threshold:0.2, J-value:0.273
# threshold:0.30000000000000004, J-value:0.109
# threshold:0.4, J-value:0.021
# threshold:0.5, J-value:0.002
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.690301754759875
# Balanced accuracy score of test is  0.6983585566245485
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      2704
#            1       0.00      0.00      0.00       262
#
#     accuracy                           0.91      2966
#    macro avg       0.46      0.50      0.48      2966
# weighted avg       0.83      0.91      0.87      2966
#
# Confusion_matrix
# [[2703    1]
#  [ 262    0]]
# done in 37.928773s
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      2762
#            1       1.00      0.00      0.01       254
#
#     accuracy                           0.92      3016
#    macro avg       0.96      0.50      0.48      3016
# weighted avg       0.92      0.92      0.88      3016
#
# Confusion_matrix
# [[2762    0]
#  [ 253    1]]
# done in 37.335244s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.348
# threshold:0.2, J-value:0.182
# threshold:0.30000000000000004, J-value:0.07
# threshold:0.4, J-value:0.006
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6738857333212882
# Balanced accuracy score of test is  0.715710115344923
# True positive rate of class 1 is  0.73
# True positive rate of class 2 is  0.669
# Positive prediction rate of class 1 is  0.37
# Positive prediction rate of class 2 is  0.274
# 0.1786415439706444
# 0.2779273363144036
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19908
#            1       0.00      0.00      0.00      1990
#
#     accuracy                           0.91     21898
#    macro avg       0.45      0.50      0.48     21898
# weighted avg       0.83      0.91      0.87     21898
#
# Confusion_matrix
# [[19906     2]
#  [ 1990     0]]
# done in 1.359187s
# 0.1786415439706444
# 0.27513160132436754
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19918
#            1       0.33      0.00      0.00      1980
#
#     accuracy                           0.91     21898
#    macro avg       0.62      0.50      0.48     21898
# weighted avg       0.86      0.91      0.87     21898
#
# Confusion_matrix
# [[19914     4]
#  [ 1978     2]]
# done in 1.342690s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.36000000000000004
# threshold:0.2, J-value:0.16799999999999998
# threshold:0.30000000000000004, J-value:0.067
# threshold:0.4, J-value:0.054000000000000006
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6798643609851549
# Balanced accuracy score of test is  0.6799715956634322
# 0.1786415439706444
# 0.273335307438619
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     17204
#            1       0.00      0.00      0.00      1728
#
#     accuracy                           0.91     18932
#    macro avg       0.45      0.50      0.48     18932
# weighted avg       0.83      0.91      0.87     18932
#
# Confusion_matrix
# [[17204     0]
#  [ 1728     0]]
# done in 1.344209s
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.1786415439706444
# 0.27347313543890395
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     17156
#            1       1.00      0.00      0.00      1726
#
#     accuracy                           0.91     18882
#    macro avg       0.95      0.50      0.48     18882
# weighted avg       0.92      0.91      0.87     18882
#
# Confusion_matrix
# [[17156     0]
#  [ 1725     1]]
# done in 1.336143s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.37
# threshold:0.2, J-value:0.17700000000000002
# threshold:0.30000000000000004, J-value:0.068
# threshold:0.4, J-value:0.059
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.68522178304787
# Balanced accuracy score of test is  0.6820844411327909
# 0.1786415439706444
# 0.3072382906894386
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      2704
#            1       0.00      0.00      0.00       262
#
#     accuracy                           0.91      2966
#    macro avg       0.46      0.50      0.48      2966
# weighted avg       0.83      0.91      0.87      2966
#
# Confusion_matrix
# [[2702    2]
#  [ 262    0]]
# done in 1.316215s
# 0.1786415439706444
# 0.28551460956353336
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      2762
#            1       0.20      0.00      0.01       254
#
#     accuracy                           0.91      3016
#    macro avg       0.56      0.50      0.48      3016
# weighted avg       0.86      0.91      0.88      3016
#
# Confusion_matrix
# [[2758    4]
#  [ 253    1]]
# done in 1.311597s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.28300000000000003
# threshold:0.2, J-value:0.10699999999999998
# threshold:0.30000000000000004, J-value:0.05499999999999999
# threshold:0.4, J-value:0.021000000000000005
# threshold:0.5, J-value:-0.001
# threshold:0.6000000000000001, J-value:-0.001
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6414331044762636
# Balanced accuracy score of test is  0.6566820801997868
# True positive rate of class 1 is  0.724
# True positive rate of class 2 is  0.453
# Positive prediction rate of class 1 is  0.393
# Positive prediction rate of class 2 is  0.166
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19908
#            1       0.52      0.03      0.06      1990
#
#     accuracy                           0.91     21898
#    macro avg       0.71      0.52      0.51     21898
# weighted avg       0.88      0.91      0.87     21898
#
# Confusion_matrix
# [[19846    62]
#  [ 1924    66]]
# done in 74.570692s
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19918
#            1       0.39      0.02      0.04      1980
#
#     accuracy                           0.91     21898
#    macro avg       0.65      0.51      0.50     21898
# weighted avg       0.86      0.91      0.87     21898
#
# Confusion_matrix
# [[19848    70]
#  [ 1936    44]]
# done in 77.208227s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.396
# threshold:0.2, J-value:0.261
# threshold:0.30000000000000004, J-value:0.147
# threshold:0.4, J-value:0.07100000000000001
# threshold:0.5, J-value:0.030000000000000002
# threshold:0.6000000000000001, J-value:0.005
# threshold:0.7000000000000001, J-value:0.001
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6976105411526186
# Balanced accuracy score of test is  0.704993402242122
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     17204
#            1       0.51      0.03      0.06      1728
#
#     accuracy                           0.91     18932
#    macro avg       0.71      0.51      0.51     18932
# weighted avg       0.87      0.91      0.87     18932
#
# Confusion_matrix
# [[17151    53]
#  [ 1672    56]]
# done in 75.184318s
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     17156
#            1       0.41      0.02      0.04      1726
#
#     accuracy                           0.91     18882
#    macro avg       0.66      0.51      0.50     18882
# weighted avg       0.86      0.91      0.87     18882
#
# Confusion_matrix
# [[17098    58]
#  [ 1686    40]]
# done in 75.564025s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.40800000000000003
# threshold:0.2, J-value:0.27599999999999997
# threshold:0.30000000000000004, J-value:0.156
# threshold:0.4, J-value:0.07300000000000001
# threshold:0.5, J-value:0.029
# threshold:0.6000000000000001, J-value:0.005
# threshold:0.7000000000000001, J-value:0.001
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7039221471966037
# Balanced accuracy score of test is  0.7090801889659797
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      2704
#            1       0.50      0.03      0.06       262
#
#     accuracy                           0.91      2966
#    macro avg       0.71      0.52      0.51      2966
# weighted avg       0.88      0.91      0.88      2966
#
# Confusion_matrix
# [[2695    9]
#  [ 253    9]]
# done in 77.098965s
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.95      2762
#            1       0.25      0.02      0.03       254
#
#     accuracy                           0.91      3016
#    macro avg       0.58      0.51      0.49      3016
# weighted avg       0.86      0.91      0.88      3016
#
# Confusion_matrix
# [[2750   12]
#  [ 250    4]]
# done in 77.612802s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.308
# threshold:0.2, J-value:0.16499999999999998
# threshold:0.30000000000000004, J-value:0.08499999999999999
# threshold:0.4, J-value:0.059000000000000004
# threshold:0.5, J-value:0.031000000000000003
# threshold:0.6000000000000001, J-value:0.007
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6540141266543205
# Balanced accuracy score of test is  0.670802282951416
# True positive rate of class 1 is  0.683
# True positive rate of class 2 is  0.453
# Positive prediction rate of class 1 is  0.303
# Positive prediction rate of class 2 is  0.14

# %%
def add_mean_sd(records, result_table):
    records.append({
        'auroc': '%.4f (+/- %.4f)' % (result_table["auroc"].mean(), result_table["auroc"].std()),
        'overall ba validation': '%.4f (+/- %.4f)' % (result_table["overall ba validation"].mean(), result_table["overall ba validation"].std()),
        'overall ba test': '%.4f (+/- %.4f)' % (result_table["overall ba test"].mean(), result_table["overall ba test"].std()),
        'white ba validation': '%.4f (+/- %.4f)' %(result_table["white ba validation"].mean(), result_table["white ba validation"].std()),
        'white ba test': '%.4f (+/- %.4f)' % (result_table["white ba test"].mean(), result_table["white ba test"].std()),
        'black ba validation': '%.4f (+/- %.4f)' % (result_table["black ba validation"].mean(), result_table["black ba validation"].std()),
        'black ba test': '%.4f (+/- %.4f)' % (result_table["black ba test"].mean(), result_table["black ba test"].std()),
        'eod': '%.4f (+/- %.4f)' % (result_table["eod"].mean(), result_table["eod"].std()),
        'di': '%.4f (+/- %.4f)' % (result_table["di"].mean(), result_table["di"].std()),
        })
    pd_result = pd.DataFrame(records)
    return pd_result

# %%
result_lr = add_mean_sd (records_lr, result_lr)
result_rf = add_mean_sd (records_rf, result_rf)
result_dt = add_mean_sd (records_dt, result_dt)
result_gbt = add_mean_sd (records_gbt, result_gbt)

result_path='/Users/lifuchen/Desktop/research/resample/'
result_lr.to_csv(path.join(result_path,'race-lr-resample-size-result.csv'), index=False)
result_rf.to_csv(path.join(result_path,'race-rf-resample-size-result.csv'), index=False)
result_dt.to_csv(path.join(result_path,'race-dt-resample-size-result.csv'), index=False)
result_gbt.to_csv(path.join(result_path,'race-gbt-resample-size-result.csv'), index=False)
