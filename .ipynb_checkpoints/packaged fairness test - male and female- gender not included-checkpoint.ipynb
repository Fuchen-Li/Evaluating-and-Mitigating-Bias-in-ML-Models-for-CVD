# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from os import path
from sklearn.metrics import balanced_accuracy_score, roc_auc_score
import sklearn.preprocessing
from sklearn import preprocessing
from sklearn.preprocessing import Normalizer
import src.lib.utility_classfier as uclf
import src.lib.optimal_threhold_related as thres
import src.lib.fairness_tests as fair

# %%
data_path='/Users/lifuchen/Desktop/research/data.csv'
df = pd.read_csv(data_path)

# %%
y = df.Class.values
X = df.drop(['GRID','Class'], axis=1)
X.shape
# Out:
# (109490, 87)

# %%
def save_prediction(classifier, characteristic, X_train_scaled, y_train, X_val_scaled, y_val, X_test_scaled, y_test, X_val_male_scaled, y_val_male, X_test_male_scaled, y_test_male, X_val_female_scaled, y_val_female, X_test_female_scaled, y_test_female):
    method_to_call = getattr(uclf, classifier)
    file_path = '/Users/lifuchen/Desktop/Evaluating-and-Mitigating-Bias-in-ML-Models-for-CVD/Models/'
    filename = str(classifier) + '_' + characteristic[-1] + '_model.sav'
    clf = method_to_call(X_train_scaled, y_train, X_test_scaled, y_test, dump_model=False, file_name = file_path + filename)
    
    y_val_score = clf.predict_proba(X_val_scaled)[:, 1]
    y_test_score = clf.predict_proba(X_test_scaled)[:, 1]
    y_val_score_male = clf.predict_proba(X_val_male_scaled)[:, 1]
    y_test_score_male = clf.predict_proba(X_test_male_scaled)[:, 1]
    y_val_score_female = clf.predict_proba(X_val_female_scaled)[:, 1]
    y_test_score_female = clf.predict_proba(X_test_female_scaled)[:, 1] 
    
    my_dict = dict(val_score = y_val_score, test_score = y_test_score, val_1_score = y_val_score_male, test_1_score = y_test_score_male, val_2_score = y_val_score_female, test_2_score = y_test_score_female)
    overall_prediction = pd.DataFrame.from_dict(my_dict, orient='index')
    overall_prediction = overall_prediction.transpose()

    result_path='/Users/lifuchen/Desktop/research/predictions/'
    filename = str(classifier) + str(characteristic) + "prediction.csv"
    overall_prediction.to_csv(path.join(result_path, filename), index=False)

# %%
def get_result (classifier,characteristic, records, X_train_scaled, y_train, X_val_scaled, y_val, X_test_scaled, y_test, X_val_male_scaled, y_val_male, X_test_male_scaled, y_test_male, X_val_female_scaled, y_val_female, X_test_female_scaled, y_test_female):
    result_path='/Users/lifuchen/Desktop/research/predictions/'
    filename = str(classifier) + characteristic + "prediction.csv"
    prediction = pd.read_csv(path.join(result_path, filename))
    
    y_val_score = prediction['val_score'][prediction['val_score'].notna()]
    y_test_score = prediction['test_score'][prediction['test_score'].notna()]
    
    y_val_score_male = prediction['val_1_score'][prediction['val_1_score'].notna()]
    y_test_score_male = prediction['test_1_score'][prediction['test_1_score'].notna()]
    
    y_val_score_female = prediction['val_2_score'][prediction['val_2_score'].notna()]
    y_test_score_female = prediction['test_2_score'][prediction['test_2_score'].notna()]
    
    threshold, ba_val, ba_test = balance_accuracy (y_val, y_val_score,y_test, y_test_score)
    auroc = roc_auc_score(y_test, y_test_score)
    precision, recall, tpr, tnr, pd_overall = thres.calculate_precision_metrics(y_test, y_test_score,threshold)
    
    threshold_male, ba_val_male, ba_test_male = balance_accuracy (y_val_male, y_val_score_male,y_test_male, y_test_score_male)
    precision_male, recall_male, tpr_male, tnr_male, pd_male = thres.calculate_precision_metrics(y_test_male, y_test_score_male,threshold_male)
    
    threshold_female, ba_val_female, ba_test_female = balance_accuracy (y_val_female, y_val_score_female, y_test_female, y_test_score_female)
    precision_female, recall_female, tpr_female, tnr_female, pd_female = thres.calculate_precision_metrics(y_test_female, y_test_score_female,threshold_female)

    eod = fair.get_EOD(y_test_male, y_test_score_male,threshold_male, y_test_female, y_test_score_female, threshold_female)
    sp = fair.get_SP(y_test_male, y_test_score_male,threshold_male, y_test_female, y_test_score_female, threshold_female)

    records.append({
        'auroc': auroc,
        'overall threshold': threshold,
        'male threshold': threshold_male,
        'female threshold': threshold_female,
        'overall ba validation': ba_val,
        'overall ba test': ba_test,
        'male ba validation': ba_val_male,
        'male ba test': ba_test_male,
        'female ba validation': ba_val_female,
        'female ba test': ba_test_female,
        'overall precision':precision,
        'overall recall':recall,
        'overall tpr':tpr,
        'overall tnr':tnr,
        'overall pd':pd_overall,
        'male precision':precision_male,
        'male recall':recall_male,
        'male tpr':tpr_male,
        'male tnr':tnr_male,
        'male pd':pd_male,
        'female precision':precision_female,
        'female recall':recall_female,
        'female tpr':tpr_female,
        'female tnr':tnr_female,
        'female pd':pd_female,
        'eod': eod,
        'di': sp,
        })

# %%
def balance_accuracy (y_val, y_val_score,y_test, y_test_score):
    
    threshold, _ = thres.get_optimal_threshold_Jvalue (y_val, y_val_score)
    print ("Optimal threshold by J value is ",threshold)

    ba_val = thres.calculate_balanced_accuracy(y_val, y_val_score, threshold)
    print ("Balanced accuracy score of val is ", ba_val)

    ba_test = thres.calculate_balanced_accuracy(y_test, y_test_score, threshold)
    print ("Balanced accuracy score of test is ",ba_test)

    return threshold, ba_val, ba_test

# %%
def fairness_metrics (X, y, attribute, random_state):
    X_train, y_train, X_val, y_val, X_test, y_test, X_val_female, X_val_male, y_val_female, y_val_male, X_test_female, X_test_male, y_test_female, y_test_male \
        = fair.split_by_trait(X, y, attribute, random_state)
    print("X train", X_train.shape[0])
    print("Y train", y_train.shape[0])
    print(X_val.shape[0], X_val_male.shape[0], X_val_female.shape[0])
    print(y_val.shape[0], y_val_male.shape[0], y_val_female.shape[0])
    print(X_test.shape[0], X_test_male.shape[0], X_test_female.shape[0])
    print(y_test.shape[0], y_test_male.shape[0], y_test_female.shape[0])

    max_abs_scaler = preprocessing.MaxAbsScaler()
    X_train_scaled = max_abs_scaler.fit_transform(X_train)
    X_test_scaled = max_abs_scaler.transform(X_test)
    X_test_male_scaled = max_abs_scaler.transform(X_test_male)
    X_test_female_scaled = max_abs_scaler.transform(X_test_female)
    X_val_scaled = max_abs_scaler.transform(X_val)
    X_val_male_scaled = max_abs_scaler.transform(X_val_male)
    X_val_female_scaled = max_abs_scaler.transform(X_val_female)

    characteristic = attribute + "_not_included_" + str(random_state)
    #save_prediction ("logic_regression", characteristic, X_train_scaled, y_train, X_val_scaled, y_val, X_test_scaled, y_test, X_val_male_scaled, y_val_male, X_test_male_scaled, y_test_male, X_val_female_scaled, y_val_female, X_test_female_scaled, y_test_female)
    #save_prediction ("random_forest", characteristic, X_train_scaled, y_train, X_val_scaled, y_val, X_test_scaled, y_test, X_val_male_scaled, y_val_male, X_test_male_scaled, y_test_male, X_val_female_scaled, y_val_female, X_test_female_scaled, y_test_female)
    #save_prediction ("decision_tree", characteristic, X_train_scaled, y_train, X_val_scaled, y_val, X_test_scaled, y_test, X_val_male_scaled, y_val_male, X_test_male_scaled, y_test_male, X_val_female_scaled, y_val_female, X_test_female_scaled, y_test_female)
    #save_prediction ("gradiant_boosting", characteristic, X_train_scaled, y_train, X_val_scaled, y_val, X_test_scaled, y_test, X_val_male_scaled, y_val_male, X_test_male_scaled, y_test_male, X_val_female_scaled, y_val_female, X_test_female_scaled, y_test_female)

    get_result ("logic_regression", characteristic, records_lr, X_train_scaled, y_train, X_val_scaled, y_val, X_test_scaled, y_test, X_val_male_scaled, y_val_male, X_test_male_scaled, y_test_male, X_val_female_scaled, y_val_female, X_test_female_scaled, y_test_female)
    get_result ("random_forest", characteristic, records_rf, X_train_scaled, y_train, X_val_scaled, y_val, X_test_scaled, y_test, X_val_male_scaled, y_val_male, X_test_male_scaled, y_test_male, X_val_female_scaled, y_val_female, X_test_female_scaled, y_test_female)
    #get_result ("decision_tree", characteristic, records_dt, X_train_scaled, y_train, X_val_scaled, y_val, X_test_scaled, y_test, X_val_male_scaled, y_val_male, X_test_male_scaled, y_test_male, X_val_female_scaled, y_val_female, X_test_female_scaled, y_test_female)
    get_result ("gradiant_boosting", characteristic, records_gbt, X_train_scaled, y_train, X_val_scaled, y_val, X_test_scaled, y_test, X_val_male_scaled, y_val_male, X_test_male_scaled, y_test_male, X_val_female_scaled, y_val_female, X_test_female_scaled, y_test_female)

# %%
records_lr = []
records_rf = []
#records_dt = []
records_gbt = []
for random_state in range(10):
    fairness_metrics (X, y, "GENDER", random_state)

result_lr = pd.DataFrame(records_lr)
result_rf = pd.DataFrame(records_rf)
#result_dt = pd.DataFrame(records_dt)
result_gbt = pd.DataFrame(records_gbt)
# Out:
# X train 65694
# Y train 65694
# 21898 7782 14116
# 21898 7782 14116
# 21898 7707 14191
# 21898 7707 14191
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.40800000000000003
# threshold:0.2, J-value:0.26299999999999996
# threshold:0.30000000000000004, J-value:0.149
# threshold:0.4, J-value:0.068
# threshold:0.5, J-value:0.031000000000000003
# threshold:0.6000000000000001, J-value:0.012
# threshold:0.7000000000000001, J-value:0.001
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7040792796395619
# Balanced accuracy score of test is  0.6966290694117472
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.38099999999999995
# threshold:0.2, J-value:0.25
# threshold:0.30000000000000004, J-value:0.131
# threshold:0.4, J-value:0.054000000000000006
# threshold:0.5, J-value:0.028
# threshold:0.6000000000000001, J-value:0.011
# threshold:0.7000000000000001, J-value:0.001
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6904875565129713
# Balanced accuracy score of test is  0.6917499939763391
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.41700000000000004
# threshold:0.2, J-value:0.267
# threshold:0.30000000000000004, J-value:0.161
# threshold:0.4, J-value:0.079
# threshold:0.5, J-value:0.032
# threshold:0.6000000000000001, J-value:0.012
# threshold:0.7000000000000001, J-value:0.001
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.708212149752268
# Balanced accuracy score of test is  0.6937760046147341
# True positive rate of class 1 is  0.7
# True positive rate of class 2 is  0.619
# Positive prediction rate of class 1 is  0.359
# Positive prediction rate of class 2 is  0.262
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.407
# threshold:0.2, J-value:0.20700000000000002
# threshold:0.30000000000000004, J-value:0.039
# threshold:0.4, J-value:0.002
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7037573230140582
# Balanced accuracy score of test is  0.6899697974803614
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.37800000000000006
# threshold:0.2, J-value:0.21399999999999997
# threshold:0.30000000000000004, J-value:0.044000000000000004
# threshold:0.4, J-value:0.003
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6887922299199123
# Balanced accuracy score of test is  0.6709942654747849
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.409
# threshold:0.2, J-value:0.197
# threshold:0.30000000000000004, J-value:0.034
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7040890787187821
# Balanced accuracy score of test is  0.6912154475269141
# True positive rate of class 1 is  0.798
# True positive rate of class 2 is  0.667
# Positive prediction rate of class 1 is  0.494
# Positive prediction rate of class 2 is  0.315
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.43099999999999994
# threshold:0.2, J-value:0.26899999999999996
# threshold:0.30000000000000004, J-value:0.11599999999999999
# threshold:0.4, J-value:0.045
# threshold:0.5, J-value:0.014
# threshold:0.6000000000000001, J-value:0.002
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7155052375776848
# Balanced accuracy score of test is  0.700081475590426
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.416
# threshold:0.2, J-value:0.275
# threshold:0.30000000000000004, J-value:0.11599999999999999
# threshold:0.4, J-value:0.046
# threshold:0.5, J-value:0.022000000000000002
# threshold:0.6000000000000001, J-value:0.002
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7080340366336659
# Balanced accuracy score of test is  0.6979429197889309
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.42500000000000004
# threshold:0.2, J-value:0.258
# threshold:0.30000000000000004, J-value:0.113
# threshold:0.4, J-value:0.043000000000000003
# threshold:0.5, J-value:0.008
# threshold:0.6000000000000001, J-value:0.001
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7126669805855108
# Balanced accuracy score of test is  0.692118474699969
# True positive rate of class 1 is  0.747
# True positive rate of class 2 is  0.611
# Positive prediction rate of class 1 is  0.395
# Positive prediction rate of class 2 is  0.257
# X train 65694
# Y train 65694
# 21898 7665 14233
# 21898 7665 14233
# 21898 7807 14091
# 21898 7807 14091
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.402
# threshold:0.2, J-value:0.27499999999999997
# threshold:0.30000000000000004, J-value:0.15
# threshold:0.4, J-value:0.07
# threshold:0.5, J-value:0.033
# threshold:0.6000000000000001, J-value:0.013999999999999999
# threshold:0.7000000000000001, J-value:0.003
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7013109825153621
# Balanced accuracy score of test is  0.6976819208366272
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.39499999999999996
# threshold:0.2, J-value:0.30000000000000004
# threshold:0.30000000000000004, J-value:0.173
# threshold:0.4, J-value:0.068
# threshold:0.5, J-value:0.032
# threshold:0.6000000000000001, J-value:0.014
# threshold:0.7000000000000001, J-value:0.002
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6972050155248486
# Balanced accuracy score of test is  0.6830143312240132
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.395
# threshold:0.2, J-value:0.25
# threshold:0.30000000000000004, J-value:0.132
# threshold:0.4, J-value:0.07200000000000001
# threshold:0.5, J-value:0.033
# threshold:0.6000000000000001, J-value:0.013000000000000001
# threshold:0.7000000000000001, J-value:0.004
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6977227456326112
# Balanced accuracy score of test is  0.7019351502832822
# True positive rate of class 1 is  0.685
# True positive rate of class 2 is  0.625
# Positive prediction rate of class 1 is  0.357
# Positive prediction rate of class 2 is  0.253
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.389
# threshold:0.2, J-value:0.22099999999999997
# threshold:0.30000000000000004, J-value:0.04
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6945556609790187
# Balanced accuracy score of test is  0.7041414834350646
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.35900000000000004
# threshold:0.2, J-value:0.255
# threshold:0.30000000000000004, J-value:0.051
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6797010928448765
# Balanced accuracy score of test is  0.6815931876774042
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.38700000000000007
# threshold:0.2, J-value:0.19
# threshold:0.30000000000000004, J-value:0.030000000000000002
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6932198932835241
# Balanced accuracy score of test is  0.709397398543839
# True positive rate of class 1 is  0.811
# True positive rate of class 2 is  0.698
# Positive prediction rate of class 1 is  0.486
# Positive prediction rate of class 2 is  0.311
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.41400000000000003
# threshold:0.2, J-value:0.26999999999999996
# threshold:0.30000000000000004, J-value:0.132
# threshold:0.4, J-value:0.049
# threshold:0.5, J-value:0.013999999999999999
# threshold:0.6000000000000001, J-value:0.003
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7069754582528305
# Balanced accuracy score of test is  0.7040779729211758
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.40900000000000003
# threshold:0.2, J-value:0.304
# threshold:0.30000000000000004, J-value:0.16
# threshold:0.4, J-value:0.068
# threshold:0.5, J-value:0.016
# threshold:0.6000000000000001, J-value:0.002
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7045629079287191
# Balanced accuracy score of test is  0.6938161332604186
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.4
# threshold:0.2, J-value:0.236
# threshold:0.30000000000000004, J-value:0.108
# threshold:0.4, J-value:0.034
# threshold:0.5, J-value:0.013000000000000001
# threshold:0.6000000000000001, J-value:0.003
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6995999878718575
# Balanced accuracy score of test is  0.702935605464694
# True positive rate of class 1 is  0.739
# True positive rate of class 2 is  0.629
# Positive prediction rate of class 1 is  0.393
# Positive prediction rate of class 2 is  0.255
# X train 65694
# Y train 65694
# 21898 7743 14155
# 21898 7743 14155
# 21898 7740 14158
# 21898 7740 14158
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.391
# threshold:0.2, J-value:0.258
# threshold:0.30000000000000004, J-value:0.139
# threshold:0.4, J-value:0.07100000000000001
# threshold:0.5, J-value:0.029
# threshold:0.6000000000000001, J-value:0.009999999999999998
# threshold:0.7000000000000001, J-value:0.003
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6958958741823759
# Balanced accuracy score of test is  0.7082979599390928
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.38599999999999995
# threshold:0.2, J-value:0.263
# threshold:0.30000000000000004, J-value:0.13699999999999998
# threshold:0.4, J-value:0.066
# threshold:0.5, J-value:0.029
# threshold:0.6000000000000001, J-value:0.008
# threshold:0.7000000000000001, J-value:0.004
# threshold:0.8, J-value:0.002
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6930740076894659
# Balanced accuracy score of test is  0.7071975218658892
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.382
# threshold:0.2, J-value:0.251
# threshold:0.30000000000000004, J-value:0.14
# threshold:0.4, J-value:0.07400000000000001
# threshold:0.5, J-value:0.030000000000000002
# threshold:0.6000000000000001, J-value:0.011
# threshold:0.7000000000000001, J-value:0.002
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6912222763831343
# Balanced accuracy score of test is  0.7030989902311092
# True positive rate of class 1 is  0.712
# True positive rate of class 2 is  0.63
# Positive prediction rate of class 1 is  0.345
# Positive prediction rate of class 2 is  0.256
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.389
# threshold:0.2, J-value:0.20800000000000002
# threshold:0.30000000000000004, J-value:0.028000000000000004
# threshold:0.4, J-value:0.001
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6941418999243488
# Balanced accuracy score of test is  0.7023415267154043
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.35300000000000004
# threshold:0.2, J-value:0.20599999999999996
# threshold:0.30000000000000004, J-value:0.03
# threshold:0.4, J-value:0.001
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6762153324120569
# Balanced accuracy score of test is  0.6938278558176517
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.39100000000000007
# threshold:0.2, J-value:0.20500000000000002
# threshold:0.30000000000000004, J-value:0.026
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6954425333379757
# Balanced accuracy score of test is  0.6978076064001981
# True positive rate of class 1 is  0.82
# True positive rate of class 2 is  0.692
# Positive prediction rate of class 1 is  0.477
# Positive prediction rate of class 2 is  0.328
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.41000000000000003
# threshold:0.2, J-value:0.259
# threshold:0.30000000000000004, J-value:0.11400000000000002
# threshold:0.4, J-value:0.046
# threshold:0.5, J-value:0.009
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7050729493137361
# Balanced accuracy score of test is  0.7142842202567401
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.41400000000000003
# threshold:0.2, J-value:0.271
# threshold:0.30000000000000004, J-value:0.119
# threshold:0.4, J-value:0.045
# threshold:0.5, J-value:0.011
# threshold:0.6000000000000001, J-value:-0.001
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7069926081245639
# Balanced accuracy score of test is  0.709837993639014
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.389
# threshold:0.2, J-value:0.242
# threshold:0.30000000000000004, J-value:0.107
# threshold:0.4, J-value:0.047
# threshold:0.5, J-value:0.008
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6944836530761463
# Balanced accuracy score of test is  0.7091816207245669
# True positive rate of class 1 is  0.756
# True positive rate of class 2 is  0.649
# Positive prediction rate of class 1 is  0.384
# Positive prediction rate of class 2 is  0.265
# X train 65694
# Y train 65694
# 21898 7751 14147
# 21898 7751 14147
# 21898 7757 14141
# 21898 7757 14141
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.395
# threshold:0.2, J-value:0.263
# threshold:0.30000000000000004, J-value:0.153
# threshold:0.4, J-value:0.078
# threshold:0.5, J-value:0.033
# threshold:0.6000000000000001, J-value:0.013000000000000001
# threshold:0.7000000000000001, J-value:0.002
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6972356255862394
# Balanced accuracy score of test is  0.7054351122430247
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.37599999999999995
# threshold:0.2, J-value:0.265
# threshold:0.30000000000000004, J-value:0.153
# threshold:0.4, J-value:0.079
# threshold:0.5, J-value:0.029
# threshold:0.6000000000000001, J-value:0.012
# threshold:0.7000000000000001, J-value:0.004
# threshold:0.8, J-value:0.002
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6880289395759622
# Balanced accuracy score of test is  0.7006725918485552
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.393
# threshold:0.2, J-value:0.257
# threshold:0.30000000000000004, J-value:0.15
# threshold:0.4, J-value:0.078
# threshold:0.5, J-value:0.035
# threshold:0.6000000000000001, J-value:0.013000000000000001
# threshold:0.7000000000000001, J-value:0.001
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6968103413587284
# Balanced accuracy score of test is  0.7013822288553712
# True positive rate of class 1 is  0.713
# True positive rate of class 2 is  0.617
# Positive prediction rate of class 1 is  0.356
# Positive prediction rate of class 2 is  0.246
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.39399999999999996
# threshold:0.2, J-value:0.2
# threshold:0.30000000000000004, J-value:0.046
# threshold:0.4, J-value:0.002
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6972276744380936
# Balanced accuracy score of test is  0.7012399068504099
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.36699999999999994
# threshold:0.2, J-value:0.194
# threshold:0.30000000000000004, J-value:0.058
# threshold:0.4, J-value:0.004
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6833852957116098
# Balanced accuracy score of test is  0.6865242283329652
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.392
# threshold:0.2, J-value:0.201
# threshold:0.30000000000000004, J-value:0.036000000000000004
# threshold:0.4, J-value:0.001
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6956451948226141
# Balanced accuracy score of test is  0.698500970043047
# True positive rate of class 1 is  0.82
# True positive rate of class 2 is  0.667
# Positive prediction rate of class 1 is  0.489
# Positive prediction rate of class 2 is  0.301
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.402
# threshold:0.2, J-value:0.27499999999999997
# threshold:0.30000000000000004, J-value:0.13
# threshold:0.4, J-value:0.048
# threshold:0.5, J-value:0.013
# threshold:0.6000000000000001, J-value:0.003
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7010071959152806
# Balanced accuracy score of test is  0.7131531704229765
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.393
# threshold:0.2, J-value:0.276
# threshold:0.30000000000000004, J-value:0.141
# threshold:0.4, J-value:0.053000000000000005
# threshold:0.5, J-value:0.018000000000000002
# threshold:0.6000000000000001, J-value:0.005
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6966102876579563
# Balanced accuracy score of test is  0.7136111943110723
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.39
# threshold:0.2, J-value:0.267
# threshold:0.30000000000000004, J-value:0.11900000000000001
# threshold:0.4, J-value:0.043
# threshold:0.5, J-value:0.009000000000000001
# threshold:0.6000000000000001, J-value:0.001
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6948615787002884
# Balanced accuracy score of test is  0.7025707584262866
# True positive rate of class 1 is  0.773
# True positive rate of class 2 is  0.622
# Positive prediction rate of class 1 is  0.393
# Positive prediction rate of class 2 is  0.249
# X train 65694
# Y train 65694
# 21898 7842 14056
# 21898 7842 14056
# 21898 7759 14139
# 21898 7759 14139
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.402
# threshold:0.2, J-value:0.26399999999999996
# threshold:0.30000000000000004, J-value:0.148
# threshold:0.4, J-value:0.069
# threshold:0.5, J-value:0.030000000000000002
# threshold:0.6000000000000001, J-value:0.012
# threshold:0.7000000000000001, J-value:0.002
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.701284831252527
# Balanced accuracy score of test is  0.7056706088018239
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.37499999999999994
# threshold:0.2, J-value:0.263
# threshold:0.30000000000000004, J-value:0.15
# threshold:0.4, J-value:0.063
# threshold:0.5, J-value:0.027000000000000003
# threshold:0.6000000000000001, J-value:0.009
# threshold:0.7000000000000001, J-value:0.001
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6878161388809998
# Balanced accuracy score of test is  0.6986155473279618
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.41100000000000003
# threshold:0.2, J-value:0.259
# threshold:0.30000000000000004, J-value:0.14500000000000002
# threshold:0.4, J-value:0.07300000000000001
# threshold:0.5, J-value:0.032
# threshold:0.6000000000000001, J-value:0.013999999999999999
# threshold:0.7000000000000001, J-value:0.001
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7053091796612315
# Balanced accuracy score of test is  0.705452681828844
# True positive rate of class 1 is  0.711
# True positive rate of class 2 is  0.643
# Positive prediction rate of class 1 is  0.355
# Positive prediction rate of class 2 is  0.264
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.401
# threshold:0.2, J-value:0.20900000000000002
# threshold:0.30000000000000004, J-value:0.03
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7004769076676574
# Balanced accuracy score of test is  0.696195348189397
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.37099999999999994
# threshold:0.2, J-value:0.232
# threshold:0.30000000000000004, J-value:0.040999999999999995
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6853768460664584
# Balanced accuracy score of test is  0.6847014767306894
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.40299999999999997
# threshold:0.2, J-value:0.189
# threshold:0.30000000000000004, J-value:0.022
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7013445517765172
# Balanced accuracy score of test is  0.694154663692125
# True positive rate of class 1 is  0.824
# True positive rate of class 2 is  0.685
# Positive prediction rate of class 1 is  0.493
# Positive prediction rate of class 2 is  0.327
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.41200000000000003
# threshold:0.2, J-value:0.27099999999999996
# threshold:0.30000000000000004, J-value:0.135
# threshold:0.4, J-value:0.044
# threshold:0.5, J-value:0.013
# threshold:0.6000000000000001, J-value:0.002
# threshold:0.7000000000000001, J-value:0.001
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.706081938631941
# Balanced accuracy score of test is  0.7082030775598984
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.399
# threshold:0.2, J-value:0.29100000000000004
# threshold:0.30000000000000004, J-value:0.153
# threshold:0.4, J-value:0.05
# threshold:0.5, J-value:0.012
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6996666429991479
# Balanced accuracy score of test is  0.7043648314143459
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.406
# threshold:0.2, J-value:0.249
# threshold:0.30000000000000004, J-value:0.11900000000000001
# threshold:0.4, J-value:0.038
# threshold:0.5, J-value:0.013999999999999999
# threshold:0.6000000000000001, J-value:0.003
# threshold:0.7000000000000001, J-value:0.001
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7030732046930751
# Balanced accuracy score of test is  0.7031943259119515
# True positive rate of class 1 is  0.759
# True positive rate of class 2 is  0.639
# Positive prediction rate of class 1 is  0.393
# Positive prediction rate of class 2 is  0.264
# X train 65694
# Y train 65694
# 21898 7814 14084
# 21898 7814 14084
# 21898 7778 14120
# 21898 7778 14120
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.389
# threshold:0.2, J-value:0.249
# threshold:0.30000000000000004, J-value:0.148
# threshold:0.4, J-value:0.07200000000000001
# threshold:0.5, J-value:0.028
# threshold:0.6000000000000001, J-value:0.013000000000000001
# threshold:0.7000000000000001, J-value:0.006
# threshold:0.8, J-value:0.002
# threshold:0.9, J-value:0.001
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6945008205487747
# Balanced accuracy score of test is  0.7048731675791677
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.39599999999999996
# threshold:0.2, J-value:0.269
# threshold:0.30000000000000004, J-value:0.146
# threshold:0.4, J-value:0.071
# threshold:0.5, J-value:0.02
# threshold:0.6000000000000001, J-value:0.012
# threshold:0.7000000000000001, J-value:0.006
# threshold:0.8, J-value:0.002
# threshold:0.9, J-value:0.001
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6979703009799287
# Balanced accuracy score of test is  0.6972341407632423
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.374
# threshold:0.2, J-value:0.22899999999999998
# threshold:0.30000000000000004, J-value:0.148
# threshold:0.4, J-value:0.07200000000000001
# threshold:0.5, J-value:0.033
# threshold:0.6000000000000001, J-value:0.012
# threshold:0.7000000000000001, J-value:0.005
# threshold:0.8, J-value:0.002
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.686851576193422
# Balanced accuracy score of test is  0.7041236263736264
# True positive rate of class 1 is  0.702
# True positive rate of class 2 is  0.627
# Positive prediction rate of class 1 is  0.35
# Positive prediction rate of class 2 is  0.251
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.391
# threshold:0.2, J-value:0.20500000000000002
# threshold:0.30000000000000004, J-value:0.037
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.695351586831152
# Balanced accuracy score of test is  0.7007733605641311
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.36299999999999993
# threshold:0.2, J-value:0.23099999999999998
# threshold:0.30000000000000004, J-value:0.041
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6813706302826357
# Balanced accuracy score of test is  0.6828905844854778
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.39100000000000007
# threshold:0.2, J-value:0.181
# threshold:0.30000000000000004, J-value:0.034
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.695567976294807
# Balanced accuracy score of test is  0.702543956043956
# True positive rate of class 1 is  0.813
# True positive rate of class 2 is  0.693
# Positive prediction rate of class 1 is  0.487
# Positive prediction rate of class 2 is  0.32
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.406
# threshold:0.2, J-value:0.252
# threshold:0.30000000000000004, J-value:0.123
# threshold:0.4, J-value:0.047
# threshold:0.5, J-value:0.015000000000000001
# threshold:0.6000000000000001, J-value:0.003
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7032185020017487
# Balanced accuracy score of test is  0.7160538935149826
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.402
# threshold:0.2, J-value:0.271
# threshold:0.30000000000000004, J-value:0.132
# threshold:0.4, J-value:0.05600000000000001
# threshold:0.5, J-value:0.016
# threshold:0.6000000000000001, J-value:0.002
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7012067854547389
# Balanced accuracy score of test is  0.709689108017012
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.395
# threshold:0.2, J-value:0.23099999999999998
# threshold:0.30000000000000004, J-value:0.116
# threshold:0.4, J-value:0.04
# threshold:0.5, J-value:0.015
# threshold:0.6000000000000001, J-value:0.003
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.697366781798811
# Balanced accuracy score of test is  0.711396978021978
# True positive rate of class 1 is  0.765
# True positive rate of class 2 is  0.64
# Positive prediction rate of class 1 is  0.391
# Positive prediction rate of class 2 is  0.251
# X train 65694
# Y train 65694
# 21898 7644 14254
# 21898 7644 14254
# 21898 7881 14017
# 21898 7881 14017
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.41800000000000004
# threshold:0.2, J-value:0.26699999999999996
# threshold:0.30000000000000004, J-value:0.14
# threshold:0.4, J-value:0.07100000000000001
# threshold:0.5, J-value:0.029
# threshold:0.6000000000000001, J-value:0.012
# threshold:0.7000000000000001, J-value:0.002
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7088966557743464
# Balanced accuracy score of test is  0.7037223485214352
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.38499999999999995
# threshold:0.2, J-value:0.255
# threshold:0.30000000000000004, J-value:0.134
# threshold:0.4, J-value:0.063
# threshold:0.5, J-value:0.019
# threshold:0.6000000000000001, J-value:0.005
# threshold:0.7000000000000001, J-value:0.002
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.692615310080946
# Balanced accuracy score of test is  0.7126770877093744
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.43000000000000005
# threshold:0.2, J-value:0.27
# threshold:0.30000000000000004, J-value:0.14300000000000002
# threshold:0.4, J-value:0.078
# threshold:0.5, J-value:0.036000000000000004
# threshold:0.6000000000000001, J-value:0.016999999999999998
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.714797413220654
# Balanced accuracy score of test is  0.6903373774517148
# True positive rate of class 1 is  0.732
# True positive rate of class 2 is  0.61
# Positive prediction rate of class 1 is  0.353
# Positive prediction rate of class 2 is  0.259
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.404
# threshold:0.2, J-value:0.21200000000000002
# threshold:0.30000000000000004, J-value:0.032
# threshold:0.4, J-value:0.001
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7018081539261827
# Balanced accuracy score of test is  0.6976259244133061
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.3549999999999999
# threshold:0.2, J-value:0.21099999999999997
# threshold:0.30000000000000004, J-value:0.044
# threshold:0.4, J-value:0.001
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6775428688631839
# Balanced accuracy score of test is  0.688799860342466
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.414
# threshold:0.2, J-value:0.20700000000000002
# threshold:0.30000000000000004, J-value:0.023
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7069954032085388
# Balanced accuracy score of test is  0.6918405118289179
# True positive rate of class 1 is  0.83
# True positive rate of class 2 is  0.678
# Positive prediction rate of class 1 is  0.494
# Positive prediction rate of class 2 is  0.324
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.42899999999999994
# threshold:0.2, J-value:0.26799999999999996
# threshold:0.30000000000000004, J-value:0.119
# threshold:0.4, J-value:0.041
# threshold:0.5, J-value:0.011
# threshold:0.6000000000000001, J-value:0.003
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7143298061593958
# Balanced accuracy score of test is  0.7094161554697245
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.402
# threshold:0.2, J-value:0.267
# threshold:0.30000000000000004, J-value:0.122
# threshold:0.4, J-value:0.046
# threshold:0.5, J-value:0.014
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7006607586789777
# Balanced accuracy score of test is  0.7206046090301925
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.43100000000000005
# threshold:0.2, J-value:0.262
# threshold:0.30000000000000004, J-value:0.114
# threshold:0.4, J-value:0.035
# threshold:0.5, J-value:0.011
# threshold:0.6000000000000001, J-value:0.004
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7154326567340556
# Balanced accuracy score of test is  0.6918650849695692
# True positive rate of class 1 is  0.781
# True positive rate of class 2 is  0.616
# Positive prediction rate of class 1 is  0.388
# Positive prediction rate of class 2 is  0.262
# X train 65694
# Y train 65694
# 21898 7795 14103
# 21898 7795 14103
# 21898 7762 14136
# 21898 7762 14136
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.404
# threshold:0.2, J-value:0.26599999999999996
# threshold:0.30000000000000004, J-value:0.145
# threshold:0.4, J-value:0.07
# threshold:0.5, J-value:0.027
# threshold:0.6000000000000001, J-value:0.008
# threshold:0.7000000000000001, J-value:0.004
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7022809938407387
# Balanced accuracy score of test is  0.6944814229966432
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.38799999999999996
# threshold:0.2, J-value:0.26
# threshold:0.30000000000000004, J-value:0.142
# threshold:0.4, J-value:0.064
# threshold:0.5, J-value:0.018000000000000002
# threshold:0.6000000000000001, J-value:0.006
# threshold:0.7000000000000001, J-value:0.002
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.694011209176512
# Balanced accuracy score of test is  0.692247397690946
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.404
# threshold:0.2, J-value:0.264
# threshold:0.30000000000000004, J-value:0.14500000000000002
# threshold:0.4, J-value:0.076
# threshold:0.5, J-value:0.035
# threshold:0.6000000000000001, J-value:0.009999999999999998
# threshold:0.7000000000000001, J-value:0.005
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7020685652936572
# Balanced accuracy score of test is  0.6898496797856368
# True positive rate of class 1 is  0.683
# True positive rate of class 2 is  0.604
# Positive prediction rate of class 1 is  0.342
# Positive prediction rate of class 2 is  0.254
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.39499999999999996
# threshold:0.2, J-value:0.21400000000000002
# threshold:0.30000000000000004, J-value:0.039
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.697374356798899
# Balanced accuracy score of test is  0.6998990812047492
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.35100000000000003
# threshold:0.2, J-value:0.21299999999999997
# threshold:0.30000000000000004, J-value:0.05
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6752590558251279
# Balanced accuracy score of test is  0.684623920107791
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.402
# threshold:0.2, J-value:0.20900000000000002
# threshold:0.30000000000000004, J-value:0.030000000000000002
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7011389637062073
# Balanced accuracy score of test is  0.6987712475662153
# True positive rate of class 1 is  0.809
# True positive rate of class 2 is  0.684
# Positive prediction rate of class 1 is  0.482
# Positive prediction rate of class 2 is  0.318
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.42999999999999994
# threshold:0.2, J-value:0.27899999999999997
# threshold:0.30000000000000004, J-value:0.127
# threshold:0.4, J-value:0.05
# threshold:0.5, J-value:0.015000000000000001
# threshold:0.6000000000000001, J-value:0.004
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7151067061647645
# Balanced accuracy score of test is  0.7105280261402362
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.407
# threshold:0.2, J-value:0.276
# threshold:0.30000000000000004, J-value:0.126
# threshold:0.4, J-value:0.054
# threshold:0.5, J-value:0.015
# threshold:0.6000000000000001, J-value:0.002
# threshold:0.7000000000000001, J-value:0.001
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7033822799825118
# Balanced accuracy score of test is  0.7091716533248791
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.42900000000000005
# threshold:0.2, J-value:0.274
# threshold:0.30000000000000004, J-value:0.126
# threshold:0.4, J-value:0.047
# threshold:0.5, J-value:0.015
# threshold:0.6000000000000001, J-value:0.004
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7148038584578318
# Balanced accuracy score of test is  0.7023398193946073
# True positive rate of class 1 is  0.747
# True positive rate of class 2 is  0.626
# Positive prediction rate of class 1 is  0.376
# Positive prediction rate of class 2 is  0.253
# X train 65694
# Y train 65694
# 21898 7804 14094
# 21898 7804 14094
# 21898 7849 14049
# 21898 7849 14049
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.397
# threshold:0.2, J-value:0.258
# threshold:0.30000000000000004, J-value:0.149
# threshold:0.4, J-value:0.07100000000000001
# threshold:0.5, J-value:0.038000000000000006
# threshold:0.6000000000000001, J-value:0.012
# threshold:0.7000000000000001, J-value:0.002
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6984623897030418
# Balanced accuracy score of test is  0.7005249860713136
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.37799999999999995
# threshold:0.2, J-value:0.265
# threshold:0.30000000000000004, J-value:0.16699999999999998
# threshold:0.4, J-value:0.074
# threshold:0.5, J-value:0.045000000000000005
# threshold:0.6000000000000001, J-value:0.011
# threshold:0.7000000000000001, J-value:0.005
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6887480818884211
# Balanced accuracy score of test is  0.6938570969002981
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.397
# threshold:0.2, J-value:0.247
# threshold:0.30000000000000004, J-value:0.132
# threshold:0.4, J-value:0.068
# threshold:0.5, J-value:0.032
# threshold:0.6000000000000001, J-value:0.013000000000000001
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6986721843648117
# Balanced accuracy score of test is  0.6995393016206515
# True positive rate of class 1 is  0.697
# True positive rate of class 2 is  0.624
# Positive prediction rate of class 1 is  0.351
# Positive prediction rate of class 2 is  0.256
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.38599999999999995
# threshold:0.2, J-value:0.22099999999999997
# threshold:0.30000000000000004, J-value:0.036
# threshold:0.4, J-value:0.001
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6934311274252041
# Balanced accuracy score of test is  0.6980753125465107
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.35000000000000003
# threshold:0.2, J-value:0.23
# threshold:0.30000000000000004, J-value:0.051000000000000004
# threshold:0.4, J-value:0.001
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6753489429249471
# Balanced accuracy score of test is  0.6748764958274287
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.388
# threshold:0.2, J-value:0.20600000000000002
# threshold:0.30000000000000004, J-value:0.022
# threshold:0.4, J-value:0.001
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6943340982551387
# Balanced accuracy score of test is  0.7040857835029071
# True positive rate of class 1 is  0.793
# True positive rate of class 2 is  0.689
# Positive prediction rate of class 1 is  0.481
# Positive prediction rate of class 2 is  0.313
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.40700000000000003
# threshold:0.2, J-value:0.26999999999999996
# threshold:0.30000000000000004, J-value:0.133
# threshold:0.4, J-value:0.049
# threshold:0.5, J-value:0.012
# threshold:0.6000000000000001, J-value:0.003
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7035893048097788
# Balanced accuracy score of test is  0.7113706539556953
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.387
# threshold:0.2, J-value:0.281
# threshold:0.30000000000000004, J-value:0.156
# threshold:0.4, J-value:0.059
# threshold:0.5, J-value:0.015
# threshold:0.6000000000000001, J-value:0.006
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6932921919287095
# Balanced accuracy score of test is  0.7073877518609614
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.403
# threshold:0.2, J-value:0.253
# threshold:0.30000000000000004, J-value:0.109
# threshold:0.4, J-value:0.040999999999999995
# threshold:0.5, J-value:0.009999999999999998
# threshold:0.6000000000000001, J-value:0.001
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.70149327661718
# Balanced accuracy score of test is  0.7060439410124253
# True positive rate of class 1 is  0.76
# True positive rate of class 2 is  0.641
# Positive prediction rate of class 1 is  0.389
# Positive prediction rate of class 2 is  0.261
# X train 65694
# Y train 65694
# 21898 7696 14202
# 21898 7696 14202
# 21898 7840 14058
# 21898 7840 14058
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.406
# threshold:0.2, J-value:0.259
# threshold:0.30000000000000004, J-value:0.158
# threshold:0.4, J-value:0.08
# threshold:0.5, J-value:0.032999999999999995
# threshold:0.6000000000000001, J-value:0.011
# threshold:0.7000000000000001, J-value:0.004
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.70327105228422
# Balanced accuracy score of test is  0.7055672860527741
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.407
# threshold:0.2, J-value:0.268
# threshold:0.30000000000000004, J-value:0.16499999999999998
# threshold:0.4, J-value:0.08700000000000001
# threshold:0.5, J-value:0.033
# threshold:0.6000000000000001, J-value:0.013000000000000001
# threshold:0.7000000000000001, J-value:0.003
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7034553057205029
# Balanced accuracy score of test is  0.7039333250551387
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.397
# threshold:0.2, J-value:0.249
# threshold:0.30000000000000004, J-value:0.151
# threshold:0.4, J-value:0.07500000000000001
# threshold:0.5, J-value:0.032
# threshold:0.6000000000000001, J-value:0.009999999999999998
# threshold:0.7000000000000001, J-value:0.004
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6982637461821757
# Balanced accuracy score of test is  0.7000893681969715
# True positive rate of class 1 is  0.723
# True positive rate of class 2 is  0.619
# Positive prediction rate of class 1 is  0.361
# Positive prediction rate of class 2 is  0.252
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.40499999999999997
# threshold:0.2, J-value:0.21200000000000002
# threshold:0.30000000000000004, J-value:0.034
# threshold:0.4, J-value:0.001
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7023753495790745
# Balanced accuracy score of test is  0.7028749610579861
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.36699999999999994
# threshold:0.2, J-value:0.247
# threshold:0.30000000000000004, J-value:0.042
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6832198645747987
# Balanced accuracy score of test is  0.6780008948334211
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.4129999999999999
# threshold:0.2, J-value:0.184
# threshold:0.30000000000000004, J-value:0.028
# threshold:0.4, J-value:0.001
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7062259749051085
# Balanced accuracy score of test is  0.7089944571635136
# True positive rate of class 1 is  0.811
# True positive rate of class 2 is  0.692
# Positive prediction rate of class 1 is  0.495
# Positive prediction rate of class 2 is  0.308
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.42000000000000004
# threshold:0.2, J-value:0.262
# threshold:0.30000000000000004, J-value:0.128
# threshold:0.4, J-value:0.04
# threshold:0.5, J-value:0.009000000000000001
# threshold:0.6000000000000001, J-value:0.001
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7099369733555885
# Balanced accuracy score of test is  0.7116452128869726
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.41600000000000004
# threshold:0.2, J-value:0.29500000000000004
# threshold:0.30000000000000004, J-value:0.151
# threshold:0.4, J-value:0.056
# threshold:0.5, J-value:0.013
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.707865426390311
# Balanced accuracy score of test is  0.7042764430831414
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.40800000000000003
# threshold:0.2, J-value:0.23399999999999999
# threshold:0.30000000000000004, J-value:0.11
# threshold:0.4, J-value:0.029
# threshold:0.5, J-value:0.006
# threshold:0.6000000000000001, J-value:0.002
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.703863557607846
# Balanced accuracy score of test is  0.7071862071735551
# True positive rate of class 1 is  0.77
# True positive rate of class 2 is  0.632
# Positive prediction rate of class 1 is  0.407
# Positive prediction rate of class 2 is  0.252

# %%
def add_mean_sd(records, result_table, overall_records, type):
    records.append({
        'auroc': result_table["auroc"].mean(),
        'overall threshold': result_table["overall threshold"].mean(),
        'male threshold': result_table["male threshold"].mean(),
        'female threshold': result_table["female threshold"].mean(),
        'overall ba validation': result_table["overall ba validation"].mean(),
        'overall ba test': result_table["overall ba test"].mean(),
        'male ba validation': result_table["male ba validation"].mean(),
        'male ba test': result_table["male ba test"].mean(),
        'female ba validation': result_table["female ba validation"].mean(),
        'female ba test': result_table["female ba test"].mean(),
        'overall precision':result_table["overall precision"].mean(),
        'overall recall':result_table["overall recall"].mean(),
        'overall tpr':result_table["overall tpr"].mean(),
        'overall tnr':result_table["overall tnr"].mean(),
        'overall pd':result_table["overall pd"].mean(),
        'male precision':result_table["male precision"].mean(),
        'male recall':result_table["male recall"].mean(),
        'male tpr':result_table["male tpr"].mean(),
        'male tnr':result_table["male tnr"].mean(),
        'male pd':result_table["male pd"].mean(),
        'female precision':result_table["female precision"].mean(),
        'female recall':result_table["female recall"].mean(),
        'female tpr':result_table["female tpr"].mean(),
        'female tnr':result_table["female tnr"].mean(),
        'female pd':result_table["female pd"].mean(),
        'eod': result_table["eod"].mean(),
        'di': result_table["di"].mean(),
        })
    records.append({
        'auroc': result_table["auroc"].std(),
        'overall threshold': result_table["overall threshold"].std(),
        'male threshold': result_table["male threshold"].std(),
        'female threshold': result_table["female threshold"].std(),
        'overall ba validation': result_table["overall ba validation"].std(),
        'overall ba test': result_table["overall ba test"].std(),
        'male ba validation': result_table["male ba validation"].std(),
        'male ba test': result_table["male ba test"].std(),
        'female ba validation': result_table["female ba validation"].std(),
        'female ba test': result_table["female ba test"].std(),
        'overall precision':result_table["overall precision"].std(),
        'overall recall':result_table["overall recall"].std(),
        'overall tpr':result_table["overall tpr"].std(),
        'overall tnr':result_table["overall tnr"].std(),
        'overall pd':result_table["overall pd"].std(),
        'male precision':result_table["male precision"].std(),
        'male recall':result_table["male recall"].std(),
        'male tpr':result_table["male tpr"].std(),
        'male tnr':result_table["male tnr"].std(),
        'male pd':result_table["male pd"].std(),
        'female precision':result_table["female precision"].std(),
        'female recall':result_table["female recall"].std(),
        'female tpr':result_table["female tpr"].std(),
        'female tnr':result_table["female tnr"].std(),
        'female pd':result_table["female pd"].std(),
        'eod': result_table["eod"].std(),
        'di': result_table["di"].std(),
        })
    overall_records.append({
        'type': type,
        'auroc': result_table["auroc"].mean(),
        'auroc_std': result_table["auroc"].std(),
        'overall threshold': result_table["overall threshold"].mean(),
        'male threshold': result_table["male threshold"].mean(),
        'female threshold': result_table["female threshold"].mean(),
        'overall ba test': result_table["overall ba test"].mean(),
        'ba_std': result_table["overall ba test"].std(),
        'male ba test': result_table["male ba test"].mean(),
        'female ba test': result_table["female ba test"].mean(),
        'overall tpr':result_table["overall tpr"].mean(),
        'overall pd':result_table["overall pd"].mean(),
        'male tpr':result_table["male tpr"].mean(),
        'male pd':result_table["male pd"].mean(),
        'female tpr':result_table["female tpr"].mean(),
        'female pd':result_table["female pd"].mean(),
        'eod': result_table["eod"].mean(),
        'eod_std': result_table["eod"].std(),
        'di': result_table["di"].mean(),
        'di_std': result_table["di"].std(),
        })
    pd_result = pd.DataFrame(records)
    return pd_result, overall_records

# %%
overall_table = []
result_lr, overall_records = add_mean_sd (records_lr, result_lr, overall_table, 'lr')
result_rf, overall_records = add_mean_sd (records_rf, result_rf, overall_records, 'rf')
#result_dt, overall_records = add_mean_sd (records_dt, result_dt, overall_records, 'dt')
result_gbt, overall_records = add_mean_sd (records_gbt, result_gbt, overall_records, 'gbt')

result_path='/Users/lifuchen/Desktop/research/resample_data/'
result_lr.to_csv(path.join(result_path,'gender-lr-result.csv'), index=False)
result_rf.to_csv(path.join(result_path,'gender-rf-result.csv'), index=False)
#result_dt.to_csv(path.join(result_path,'gender-dt-result.csv'), index=False)
result_gbt.to_csv(path.join(result_path,'gender-gbt-result.csv'), index=False)

overall_result = pd.DataFrame(overall_table)
result_path='/Users/lifuchen/Desktop/research/resample_result/'
overall_result.to_csv(path.join(result_path,'gender.csv'), index=False)
