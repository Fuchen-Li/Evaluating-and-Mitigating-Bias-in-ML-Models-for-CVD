# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from os import path
from sklearn.metrics import balanced_accuracy_score, roc_auc_score
import sklearn.preprocessing
from sklearn import preprocessing
from sklearn.preprocessing import Normalizer
import src.lib.utility_classfier as uclf
import src.lib.optimal_threhold_related as thres
import src.lib.fairness_tests as fair

# %%
data_path='/Users/lifuchen/Desktop/research/data.csv'
df = pd.read_csv(data_path)

# %%
y = df.Class.values
X = df.drop(['GRID','Class'], axis=1)
X.shape
# Out:
# (109490, 87)

# %%
def save_prediction(classifier, characteristic, X_train_scaled, y_train, X_val_scaled, y_val, X_test_scaled, y_test, X_val_male_scaled, y_val_male, X_test_male_scaled, y_test_male, X_val_female_scaled, y_val_female, X_test_female_scaled, y_test_female):
    method_to_call = getattr(uclf, classifier)
    file_path = '/Users/lifuchen/Desktop/Evaluating-and-Mitigating-Bias-in-ML-Models-for-CVD/Models/'
    filename = str(classifier) + '_' + characteristic[-1] + '_model.sav'
    clf = method_to_call(X_train_scaled, y_train, X_test_scaled, y_test, dump_model=False, file_name = file_path + filename)
    
    y_val_score = clf.predict_proba(X_val_scaled)[:, 1]
    y_test_score = clf.predict_proba(X_test_scaled)[:, 1]
    y_val_score_male = clf.predict_proba(X_val_male_scaled)[:, 1]
    y_test_score_male = clf.predict_proba(X_test_male_scaled)[:, 1]
    y_val_score_female = clf.predict_proba(X_val_female_scaled)[:, 1]
    y_test_score_female = clf.predict_proba(X_test_female_scaled)[:, 1] 
    
    my_dict = dict(val_score = y_val_score, test_score = y_test_score, val_1_score = y_val_score_male, test_1_score = y_test_score_male, val_2_score = y_val_score_female, test_2_score = y_test_score_female)
    overall_prediction = pd.DataFrame.from_dict(my_dict, orient='index')
    overall_prediction = overall_prediction.transpose()

    result_path='/Users/lifuchen/Desktop/research/predictions/'
    filename = str(classifier) + str(characteristic) + "prediction.csv"
    overall_prediction.to_csv(path.join(result_path, filename), index=False)

# %%
def get_result (classifier, characteristic, records, X_train_scaled, y_train, X_val_scaled, y_val, X_test_scaled, y_test, X_val_white_scaled, y_val_white, X_test_white_scaled, y_test_white, X_val_black_scaled, y_val_black, X_test_black_scaled, y_test_black):
    result_path='/Users/lifuchen/Desktop/research/predictions/'
    filename = str(classifier) + characteristic + "prediction.csv"
    prediction = pd.read_csv(path.join(result_path, filename))

    y_val_score = prediction['val_score'][prediction['val_score'].notna()]
    y_test_score = prediction['test_score'][prediction['test_score'].notna()]

    y_val_score_white = prediction['val_1_score'][prediction['val_1_score'].notna()]
    y_test_score_white = prediction['test_1_score'][prediction['test_1_score'].notna()]

    y_val_score_black = prediction['val_2_score'][prediction['val_2_score'].notna()]
    y_test_score_black = prediction['test_2_score'][prediction['test_2_score'].notna()]

    threshold, ba_val, ba_test = balance_accuracy (y_val, y_val_score,y_test, y_test_score)
    auroc = roc_auc_score(y_test, y_test_score)
    precision, recall, tpr, tnr, pd_overall = thres.calculate_precision_metrics(y_test, y_test_score,threshold)

    threshold_white, ba_val_white, ba_test_white = balance_accuracy (y_val_white, y_val_score_white,y_test_white, y_test_score_white)
    precision_white, recall_white, tpr_white, tnr_white, pd_white = thres.calculate_precision_metrics(y_test_white, y_test_score_white,threshold_white)

    threshold_black, ba_val_black, ba_test_black = balance_accuracy (y_val_black, y_val_score_black, y_test_black, y_test_score_black)
    precision_black, recall_black, tpr_black, tnr_black, pd_black = thres.calculate_precision_metrics(y_test_black, y_test_score_black,threshold_black)

    eod = fair.get_EOD(y_test_white, y_test_score_white,threshold_white, y_test_black, y_test_score_black, threshold_black)
    sp = fair.get_SP(y_test_white, y_test_score_white,threshold_white, y_test_black, y_test_score_black, threshold_black)

    records.append({
        'auroc': auroc,
        'overall threshold': threshold,
        'white threshold': threshold_white,
        'black threshold': threshold_black,
        'overall ba validation': ba_val,
        'overall ba test': ba_test,
        'white ba validation': ba_val_white,
        'white ba test': ba_test_white,
        'black ba validation': ba_val_black,
        'black ba test': ba_test_black,
        'overall precision':precision,
        'overall recall':recall,
        'overall tpr':tpr,
        'overall tnr':tnr,
        'overall pd':pd_overall,
        'white precision':precision_white,
        'white recall':recall_white,
        'white tpr':tpr_white,
        'white tnr':tnr_white,
        'white pd':pd_white,
        'black precision':precision_black,
        'black recall':recall_black,
        'black tpr':tpr_black,
        'black tnr':tnr_black,
        'black pd':pd_black,
        'eod': eod,
        'di': sp,
        })

# %%
def balance_accuracy (y_val, y_val_score,y_test, y_test_score):
    
    threshold, _ = thres.get_optimal_threshold_Jvalue (y_val, y_val_score)
    print ("Optimal threshold by J value is ",threshold)

    ba_val = thres.calculate_balanced_accuracy(y_val, y_val_score, threshold)
    print ("Balanced accuracy score of val is ", ba_val)

    ba_test = thres.calculate_balanced_accuracy(y_test, y_test_score, threshold)
    print ("Balanced accuracy score of test is ",ba_test)

    return threshold, ba_val, ba_test

# %%
def fairness_metrics (X, y, attribute, random_state):
    X_train, y_train, X_val, y_val, X_test, y_test, X_val_white, X_val_black, y_val_white, y_val_black, X_test_white, X_test_black, y_test_white, y_test_black \
        = fair.split_by_trait_no_protected_trait(X, y, attribute, random_state)
    print("X train", X_train.shape[0])
    print("Y train", y_train.shape[0])
    print(X_val.shape[0], X_val_white.shape[0], X_val_black.shape[0])
    print(y_val.shape[0], y_val_white.shape[0], y_val_black.shape[0])
    print(X_test.shape[0], X_test_white.shape[0], X_test_black.shape[0])
    print(y_test.shape[0], y_test_white.shape[0], y_test_black.shape[0])

    max_abs_scaler = preprocessing.MaxAbsScaler()
    X_train_scaled = max_abs_scaler.fit_transform(X_train)
    X_test_scaled = max_abs_scaler.transform(X_test)
    X_test_white_scaled = max_abs_scaler.transform(X_test_white)
    X_test_black_scaled = max_abs_scaler.transform(X_test_black)
    X_val_scaled = max_abs_scaler.transform(X_val)
    X_val_white_scaled = max_abs_scaler.transform(X_val_white)
    X_val_black_scaled = max_abs_scaler.transform(X_val_black)

    characteristic = attribute + '_included_' + str(random_state) 
    save_prediction ("logic_regression", characteristic, X_train_scaled, y_train, X_val_scaled, y_val, X_test_scaled, y_test, X_val_white_scaled, y_val_white, X_test_white_scaled, y_test_white, X_val_black_scaled, y_val_black, X_test_black_scaled, y_test_black)
    save_prediction ("random_forest", characteristic, X_train_scaled, y_train, X_val_scaled, y_val, X_test_scaled, y_test, X_val_white_scaled, y_val_white, X_test_white_scaled, y_test_white, X_val_black_scaled, y_val_black, X_test_black_scaled, y_test_black)
    #save_prediction ("decision_tree", characteristic, X_train_scaled, y_train, X_val_scaled, y_val, X_test_scaled, y_test, X_val_white_scaled, y_val_white, X_test_white_scaled, y_test_white, X_val_black_scaled, y_val_black, X_test_black_scaled, y_test_black)
    save_prediction ("gradiant_boosting", characteristic, X_train_scaled, y_train, X_val_scaled, y_val, X_test_scaled, y_test, X_val_white_scaled, y_val_white, X_test_white_scaled, y_test_white, X_val_black_scaled, y_val_black, X_test_black_scaled, y_test_black)

    get_result ("logic_regression", characteristic, records_lr, X_train_scaled, y_train, X_val_scaled, y_val, X_test_scaled, y_test, X_val_white_scaled, y_val_white, X_test_white_scaled, y_test_white, X_val_black_scaled, y_val_black, X_test_black_scaled, y_test_black)
    get_result ("random_forest", characteristic, records_rf, X_train_scaled, y_train, X_val_scaled, y_val, X_test_scaled, y_test, X_val_white_scaled, y_val_white, X_test_white_scaled, y_test_white, X_val_black_scaled, y_val_black, X_test_black_scaled, y_test_black)
    #get_result ("decision_tree", characteristic, records_dt, X_train_scaled, y_train, X_val_scaled, y_val, X_test_scaled, y_test, X_val_white_scaled, y_val_white, X_test_white_scaled, y_test_white, X_val_black_scaled, y_val_black, X_test_black_scaled, y_test_black)
    get_result ("gradiant_boosting", characteristic, records_gbt, X_train_scaled, y_train, X_val_scaled, y_val, X_test_scaled, y_test, X_val_white_scaled, y_val_white, X_test_white_scaled, y_test_white, X_val_black_scaled, y_val_black, X_test_black_scaled, y_test_black)

# %%
records_lr = []
records_rf = []
#records_dt = []
records_gbt = []
for random_state in range(10):
    fairness_metrics (X, y, "Race_W", random_state)

result_lr = pd.DataFrame(records_lr)
result_rf = pd.DataFrame(records_rf)
#result_dt = pd.DataFrame(records_dt)
result_gbt = pd.DataFrame(records_gbt)
# Out:
# X train 65694
# Y train 65694
# 21898 18899 2999
# 21898 18899 2999
# 21898 18968 2930
# 21898 18968 2930
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1315: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# 0.25884953726474685
# 0.2621818978817408
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19934
#            1       0.43      0.03      0.06      1964
#
#     accuracy                           0.91     21898
#    macro avg       0.67      0.51      0.51     21898
# weighted avg       0.87      0.91      0.87     21898
#
# Confusion_matrix
# [[19851    83]
#  [ 1902    62]]
# done in 11.378848s
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19934
#            1       0.00      0.00      0.00      1964
#
#     accuracy                           0.91     21898
#    macro avg       0.46      0.50      0.48     21898
# weighted avg       0.83      0.91      0.87     21898
#
# Confusion_matrix
# [[19934     0]
#  [ 1964     0]]
# done in 6.309473s
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19934
#            1       0.47      0.02      0.03      1964
#
#     accuracy                           0.91     21898
#    macro avg       0.69      0.51      0.49     21898
# weighted avg       0.87      0.91      0.87     21898
#
# Confusion_matrix
# [[19895    39]
#  [ 1929    35]]
# done in 76.239591s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.41100000000000003
# threshold:0.2, J-value:0.26599999999999996
# threshold:0.30000000000000004, J-value:0.151
# threshold:0.4, J-value:0.07
# threshold:0.5, J-value:0.029
# threshold:0.6000000000000001, J-value:0.012
# threshold:0.7000000000000001, J-value:0.001
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7051320762931883
# Balanced accuracy score of test is  0.6988199806816671
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.404
# threshold:0.2, J-value:0.259
# threshold:0.30000000000000004, J-value:0.151
# threshold:0.4, J-value:0.068
# threshold:0.5, J-value:0.028
# threshold:0.6000000000000001, J-value:0.011
# threshold:0.7000000000000001, J-value:0.001
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7017850213426464
# Balanced accuracy score of test is  0.6989596364731709
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.45200000000000007
# threshold:0.2, J-value:0.31
# threshold:0.30000000000000004, J-value:0.156
# threshold:0.4, J-value:0.082
# threshold:0.5, J-value:0.035
# threshold:0.6000000000000001, J-value:0.013999999999999999
# threshold:0.7000000000000001, J-value:-0.001
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7261620611400347
# Balanced accuracy score of test is  0.6975665552543007
# True positive rate of class 1 is  0.662
# True positive rate of class 2 is  0.637
# Positive prediction rate of class 1 is  0.3
# Positive prediction rate of class 2 is  0.276
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.40099999999999997
# threshold:0.2, J-value:0.198
# threshold:0.30000000000000004, J-value:0.031
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7004185536916214
# Balanced accuracy score of test is  0.6897276797545955
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.394
# threshold:0.2, J-value:0.189
# threshold:0.30000000000000004, J-value:0.03
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6971071114388865
# Balanced accuracy score of test is  0.6910241763251661
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.442
# threshold:0.2, J-value:0.264
# threshold:0.30000000000000004, J-value:0.034
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7212261380323055
# Balanced accuracy score of test is  0.6806983919222139
# True positive rate of class 1 is  0.734
# True positive rate of class 2 is  0.688
# Positive prediction rate of class 1 is  0.387
# Positive prediction rate of class 2 is  0.358
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.42799999999999994
# threshold:0.2, J-value:0.267
# threshold:0.30000000000000004, J-value:0.11699999999999999
# threshold:0.4, J-value:0.044
# threshold:0.5, J-value:0.013000000000000001
# threshold:0.6000000000000001, J-value:0.002
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7138253335166271
# Balanced accuracy score of test is  0.6990104258513379
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.42099999999999993
# threshold:0.2, J-value:0.261
# threshold:0.30000000000000004, J-value:0.11699999999999999
# threshold:0.4, J-value:0.045
# threshold:0.5, J-value:0.012
# threshold:0.6000000000000001, J-value:0.002
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.710451124560737
# Balanced accuracy score of test is  0.7009097668663042
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.47
# threshold:0.2, J-value:0.301
# threshold:0.30000000000000004, J-value:0.127
# threshold:0.4, J-value:0.04
# threshold:0.5, J-value:0.013
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7349479375250301
# Balanced accuracy score of test is  0.6863269563388182
# True positive rate of class 1 is  0.674
# True positive rate of class 2 is  0.645
# Positive prediction rate of class 1 is  0.309
# Positive prediction rate of class 2 is  0.304
# X train 65694
# Y train 65694
# 21898 18825 3073
# 21898 18825 3073
# 21898 18883 3015
# 21898 18883 3015
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1315: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# 0.26212332005104655
# 0.2578680186569327
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19972
#            1       0.42      0.03      0.06      1926
#
#     accuracy                           0.91     21898
#    macro avg       0.67      0.51      0.51     21898
# weighted avg       0.87      0.91      0.87     21898
#
# Confusion_matrix
# [[19887    85]
#  [ 1864    62]]
# done in 10.083406s
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19972
#            1       0.00      0.00      0.00      1926
#
#     accuracy                           0.91     21898
#    macro avg       0.46      0.50      0.48     21898
# weighted avg       0.83      0.91      0.87     21898
#
# Confusion_matrix
# [[19972     0]
#  [ 1926     0]]
# done in 5.807057s
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19972
#            1       0.45      0.02      0.03      1926
#
#     accuracy                           0.91     21898
#    macro avg       0.68      0.51      0.49     21898
# weighted avg       0.87      0.91      0.87     21898
#
# Confusion_matrix
# [[19936    36]
#  [ 1896    30]]
# done in 76.585532s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.40700000000000003
# threshold:0.2, J-value:0.27299999999999996
# threshold:0.30000000000000004, J-value:0.152
# threshold:0.4, J-value:0.069
# threshold:0.5, J-value:0.033
# threshold:0.6000000000000001, J-value:0.013000000000000001
# threshold:0.7000000000000001, J-value:0.004
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7039137155925477
# Balanced accuracy score of test is  0.6974566053950089
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.406
# threshold:0.2, J-value:0.27799999999999997
# threshold:0.30000000000000004, J-value:0.153
# threshold:0.4, J-value:0.067
# threshold:0.5, J-value:0.030000000000000002
# threshold:0.6000000000000001, J-value:0.012
# threshold:0.7000000000000001, J-value:0.003
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7028262523272344
# Balanced accuracy score of test is  0.6991418235558289
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.42100000000000004
# threshold:0.2, J-value:0.241
# threshold:0.30000000000000004, J-value:0.154
# threshold:0.4, J-value:0.085
# threshold:0.5, J-value:0.051000000000000004
# threshold:0.6000000000000001, J-value:0.019999999999999997
# threshold:0.7000000000000001, J-value:0.006
# threshold:0.8, J-value:-0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7106402648608927
# Balanced accuracy score of test is  0.6833076097572739
# True positive rate of class 1 is  0.659
# True positive rate of class 2 is  0.59
# Positive prediction rate of class 1 is  0.296
# Positive prediction rate of class 2 is  0.252
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.39199999999999996
# threshold:0.2, J-value:0.21999999999999997
# threshold:0.30000000000000004, J-value:0.036000000000000004
# threshold:0.4, J-value:0.002
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6958236390718142
# Balanced accuracy score of test is  0.6962744207414784
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.39
# threshold:0.2, J-value:0.22199999999999998
# threshold:0.30000000000000004, J-value:0.035
# threshold:0.4, J-value:0.002
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6950796026009461
# Balanced accuracy score of test is  0.6956148767313721
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.40099999999999997
# threshold:0.2, J-value:0.20600000000000002
# threshold:0.30000000000000004, J-value:0.041
# threshold:0.4, J-value:0.003
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7004854202717616
# Balanced accuracy score of test is  0.6982556702398321
# True positive rate of class 1 is  0.738
# True positive rate of class 2 is  0.699
# Positive prediction rate of class 1 is  0.382
# Positive prediction rate of class 2 is  0.334
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.41200000000000003
# threshold:0.2, J-value:0.27199999999999996
# threshold:0.30000000000000004, J-value:0.128
# threshold:0.4, J-value:0.047
# threshold:0.5, J-value:0.013000000000000001
# threshold:0.6000000000000001, J-value:0.003
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7056219671183175
# Balanced accuracy score of test is  0.7077254989799842
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.41200000000000003
# threshold:0.2, J-value:0.27599999999999997
# threshold:0.30000000000000004, J-value:0.134
# threshold:0.4, J-value:0.046
# threshold:0.5, J-value:0.013000000000000001
# threshold:0.6000000000000001, J-value:0.002
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7059499262092552
# Balanced accuracy score of test is  0.7067285571023052
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.40700000000000003
# threshold:0.2, J-value:0.25
# threshold:0.30000000000000004, J-value:0.093
# threshold:0.4, J-value:0.053
# threshold:0.5, J-value:0.013
# threshold:0.6000000000000001, J-value:0.004
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7036842424098759
# Balanced accuracy score of test is  0.7131502236745324
# True positive rate of class 1 is  0.683
# True positive rate of class 2 is  0.669
# Positive prediction rate of class 1 is  0.307
# Positive prediction rate of class 2 is  0.277
# X train 65694
# Y train 65694
# 21898 18936 2962
# 21898 18936 2962
# 21898 18829 3069
# 21898 18829 3069
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1315: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# 0.25945802273225005
# 0.26226504777522075
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19883
#            1       0.53      0.03      0.06      2015
#
#     accuracy                           0.91     21898
#    macro avg       0.72      0.51      0.50     21898
# weighted avg       0.88      0.91      0.87     21898
#
# Confusion_matrix
# [[19831    52]
#  [ 1956    59]]
# done in 10.015808s
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19883
#            1       0.00      0.00      0.00      2015
#
#     accuracy                           0.91     21898
#    macro avg       0.45      0.50      0.48     21898
# weighted avg       0.82      0.91      0.86     21898
#
# Confusion_matrix
# [[19883     0]
#  [ 2015     0]]
# done in 5.724017s
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19883
#            1       0.53      0.01      0.02      2015
#
#     accuracy                           0.91     21898
#    macro avg       0.72      0.51      0.49     21898
# weighted avg       0.87      0.91      0.87     21898
#
# Confusion_matrix
# [[19861    22]
#  [ 1990    25]]
# done in 83.942022s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.394
# threshold:0.2, J-value:0.257
# threshold:0.30000000000000004, J-value:0.144
# threshold:0.4, J-value:0.07
# threshold:0.5, J-value:0.028
# threshold:0.6000000000000001, J-value:0.009000000000000001
# threshold:0.7000000000000001, J-value:0.002
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6970409596887497
# Balanced accuracy score of test is  0.7063782931638921
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.384
# threshold:0.2, J-value:0.249
# threshold:0.30000000000000004, J-value:0.14300000000000002
# threshold:0.4, J-value:0.066
# threshold:0.5, J-value:0.024
# threshold:0.6000000000000001, J-value:0.009000000000000001
# threshold:0.7000000000000001, J-value:0.001
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6921437574413554
# Balanced accuracy score of test is  0.7100043495353525
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.4580000000000001
# threshold:0.2, J-value:0.311
# threshold:0.30000000000000004, J-value:0.156
# threshold:0.4, J-value:0.096
# threshold:0.5, J-value:0.051000000000000004
# threshold:0.6000000000000001, J-value:0.007
# threshold:0.7000000000000001, J-value:0.004
# threshold:0.8, J-value:0.004
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7292027022856563
# Balanced accuracy score of test is  0.6822652275724705
# True positive rate of class 1 is  0.671
# True positive rate of class 2 is  0.611
# Positive prediction rate of class 1 is  0.29
# Positive prediction rate of class 2 is  0.278
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.38899999999999996
# threshold:0.2, J-value:0.202
# threshold:0.30000000000000004, J-value:0.038
# threshold:0.4, J-value:0.001
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.694438354613433
# Balanced accuracy score of test is  0.7021518563497203
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.375
# threshold:0.2, J-value:0.2
# threshold:0.30000000000000004, J-value:0.039
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6873848962400182
# Balanced accuracy score of test is  0.7045017356318954
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.48100000000000004
# threshold:0.2, J-value:0.22099999999999997
# threshold:0.30000000000000004, J-value:0.036
# threshold:0.4, J-value:0.004
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7405670567453535
# Balanced accuracy score of test is  0.6859715231609829
# True positive rate of class 1 is  0.75
# True positive rate of class 2 is  0.694
# Positive prediction rate of class 1 is  0.379
# Positive prediction rate of class 2 is  0.355
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.41600000000000004
# threshold:0.2, J-value:0.257
# threshold:0.30000000000000004, J-value:0.11100000000000002
# threshold:0.4, J-value:0.047
# threshold:0.5, J-value:0.006
# threshold:0.6000000000000001, J-value:0.001
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7081660002161461
# Balanced accuracy score of test is  0.7126947980674538
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.404
# threshold:0.2, J-value:0.255
# threshold:0.30000000000000004, J-value:0.11
# threshold:0.4, J-value:0.045
# threshold:0.5, J-value:0.006
# threshold:0.6000000000000001, J-value:0.001
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7015862950430707
# Balanced accuracy score of test is  0.7156081570516842
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.504
# threshold:0.2, J-value:0.27699999999999997
# threshold:0.30000000000000004, J-value:0.126
# threshold:0.4, J-value:0.061000000000000006
# threshold:0.5, J-value:0.012
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7518535228323151
# Balanced accuracy score of test is  0.6939836621537965
# True positive rate of class 1 is  0.697
# True positive rate of class 2 is  0.668
# Positive prediction rate of class 1 is  0.305
# Positive prediction rate of class 2 is  0.313
# X train 65694
# Y train 65694
# 21898 18932 2966
# 21898 18932 2966
# 21898 18882 3016
# 21898 18882 3016
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1315: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# 0.2588705224972624
# 0.2608286573776988
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19918
#            1       0.45      0.03      0.06      1980
#
#     accuracy                           0.91     21898
#    macro avg       0.68      0.51      0.51     21898
# weighted avg       0.87      0.91      0.87     21898
#
# Confusion_matrix
# [[19841    77]
#  [ 1918    62]]
# done in 10.379616s
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19918
#            1       0.00      0.00      0.00      1980
#
#     accuracy                           0.91     21898
#    macro avg       0.45      0.50      0.48     21898
# weighted avg       0.83      0.91      0.87     21898
#
# Confusion_matrix
# [[19918     0]
#  [ 1980     0]]
# done in 5.874747s
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19918
#            1       0.43      0.01      0.02      1980
#
#     accuracy                           0.91     21898
#    macro avg       0.67      0.50      0.49     21898
# weighted avg       0.87      0.91      0.87     21898
#
# Confusion_matrix
# [[19892    26]
#  [ 1960    20]]
# done in 79.814765s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.395
# threshold:0.2, J-value:0.26
# threshold:0.30000000000000004, J-value:0.153
# threshold:0.4, J-value:0.075
# threshold:0.5, J-value:0.033
# threshold:0.6000000000000001, J-value:0.013000000000000001
# threshold:0.7000000000000001, J-value:0.003
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6974371556395601
# Balanced accuracy score of test is  0.7093500016735281
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.394
# threshold:0.2, J-value:0.259
# threshold:0.30000000000000004, J-value:0.155
# threshold:0.4, J-value:0.07200000000000001
# threshold:0.5, J-value:0.031000000000000003
# threshold:0.6000000000000001, J-value:0.012
# threshold:0.7000000000000001, J-value:0.002
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6969310808425259
# Balanced accuracy score of test is  0.70877084714002
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.401
# threshold:0.2, J-value:0.261
# threshold:0.30000000000000004, J-value:0.147
# threshold:0.4, J-value:0.094
# threshold:0.5, J-value:0.043000000000000003
# threshold:0.6000000000000001, J-value:0.022
# threshold:0.7000000000000001, J-value:0.008
# threshold:0.8, J-value:0.004
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7006625750937261
# Balanced accuracy score of test is  0.7120453625411234
# True positive rate of class 1 is  0.67
# True positive rate of class 2 is  0.646
# Positive prediction rate of class 1 is  0.29
# Positive prediction rate of class 2 is  0.257
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.38799999999999996
# threshold:0.2, J-value:0.201
# threshold:0.30000000000000004, J-value:0.041
# threshold:0.4, J-value:0.001
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.693861486455787
# Balanced accuracy score of test is  0.7029914568924509
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.38399999999999995
# threshold:0.2, J-value:0.203
# threshold:0.30000000000000004, J-value:0.043000000000000003
# threshold:0.4, J-value:0.001
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6920528683036675
# Balanced accuracy score of test is  0.7003688057001027
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.412
# threshold:0.2, J-value:0.184
# threshold:0.30000000000000004, J-value:0.025
# threshold:0.4, J-value:0.004
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7055987171958986
# Balanced accuracy score of test is  0.719440437432649
# True positive rate of class 1 is  0.74
# True positive rate of class 2 is  0.744
# Positive prediction rate of class 1 is  0.376
# Positive prediction rate of class 2 is  0.342
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.398
# threshold:0.2, J-value:0.266
# threshold:0.30000000000000004, J-value:0.123
# threshold:0.4, J-value:0.046
# threshold:0.5, J-value:0.015
# threshold:0.6000000000000001, J-value:0.004
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6987711058810225
# Balanced accuracy score of test is  0.7139669361554088
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.396
# threshold:0.2, J-value:0.26899999999999996
# threshold:0.30000000000000004, J-value:0.126
# threshold:0.4, J-value:0.046
# threshold:0.5, J-value:0.015
# threshold:0.6000000000000001, J-value:0.004
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6981842885375493
# Balanced accuracy score of test is  0.7111901636323701
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.406
# threshold:0.2, J-value:0.24700000000000003
# threshold:0.30000000000000004, J-value:0.10500000000000001
# threshold:0.4, J-value:0.046
# threshold:0.5, J-value:0.013
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.702801052441393
# Balanced accuracy score of test is  0.731955618147297
# True positive rate of class 1 is  0.689
# True positive rate of class 2 is  0.709
# Positive prediction rate of class 1 is  0.305
# Positive prediction rate of class 2 is  0.284
# X train 65694
# Y train 65694
# 21898 18875 3023
# 21898 18875 3023
# 21898 19009 2889
# 21898 19009 2889
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1315: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# 0.26307527616800563
# 0.2563454323731131
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.95     19975
#            1       0.49      0.04      0.08      1923
#
#     accuracy                           0.91     21898
#    macro avg       0.70      0.52      0.51     21898
# weighted avg       0.88      0.91      0.88     21898
#
# Confusion_matrix
# [[19892    83]
#  [ 1844    79]]
# done in 13.039648s
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19975
#            1       0.00      0.00      0.00      1923
#
#     accuracy                           0.91     21898
#    macro avg       0.46      0.50      0.48     21898
# weighted avg       0.83      0.91      0.87     21898
#
# Confusion_matrix
# [[19975     0]
#  [ 1923     0]]
# done in 6.444504s
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19975
#            1       0.49      0.02      0.03      1923
#
#     accuracy                           0.91     21898
#    macro avg       0.70      0.51      0.49     21898
# weighted avg       0.88      0.91      0.87     21898
#
# Confusion_matrix
# [[19941    34]
#  [ 1890    33]]
# done in 88.164378s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.402
# threshold:0.2, J-value:0.264
# threshold:0.30000000000000004, J-value:0.147
# threshold:0.4, J-value:0.067
# threshold:0.5, J-value:0.028
# threshold:0.6000000000000001, J-value:0.01
# threshold:0.7000000000000001, J-value:0.002
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7010349062300338
# Balanced accuracy score of test is  0.7047000247969868
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.397
# threshold:0.2, J-value:0.262
# threshold:0.30000000000000004, J-value:0.143
# threshold:0.4, J-value:0.062
# threshold:0.5, J-value:0.026
# threshold:0.6000000000000001, J-value:0.009000000000000001
# threshold:0.7000000000000001, J-value:0.001
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6985014159907601
# Balanced accuracy score of test is  0.7020099497818576
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.43400000000000005
# threshold:0.2, J-value:0.28300000000000003
# threshold:0.30000000000000004, J-value:0.16599999999999998
# threshold:0.4, J-value:0.099
# threshold:0.5, J-value:0.046
# threshold:0.6000000000000001, J-value:0.016
# threshold:0.7000000000000001, J-value:0.003
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7169834728121451
# Balanced accuracy score of test is  0.7240116590726347
# True positive rate of class 1 is  0.667
# True positive rate of class 2 is  0.696
# Positive prediction rate of class 1 is  0.3
# Positive prediction rate of class 2 is  0.283
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.4
# threshold:0.2, J-value:0.21100000000000002
# threshold:0.30000000000000004, J-value:0.04
# threshold:0.4, J-value:0.001
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7000483364504391
# Balanced accuracy score of test is  0.6949913601049674
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.397
# threshold:0.2, J-value:0.21300000000000002
# threshold:0.30000000000000004, J-value:0.041
# threshold:0.4, J-value:0.001
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6986231334788264
# Balanced accuracy score of test is  0.6922696226991852
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.418
# threshold:0.2, J-value:0.202
# threshold:0.30000000000000004, J-value:0.03900000000000001
# threshold:0.4, J-value:0.004
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.708747213928256
# Balanced accuracy score of test is  0.7131055682122756
# True positive rate of class 1 is  0.739
# True positive rate of class 2 is  0.746
# Positive prediction rate of class 1 is  0.389
# Positive prediction rate of class 2 is  0.352
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.40800000000000003
# threshold:0.2, J-value:0.26599999999999996
# threshold:0.30000000000000004, J-value:0.127
# threshold:0.4, J-value:0.046
# threshold:0.5, J-value:0.012
# threshold:0.6000000000000001, J-value:0.001
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7038927962203305
# Balanced accuracy score of test is  0.7063135471601593
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.405
# threshold:0.2, J-value:0.27099999999999996
# threshold:0.30000000000000004, J-value:0.127
# threshold:0.4, J-value:0.044000000000000004
# threshold:0.5, J-value:0.011
# threshold:0.6000000000000001, J-value:0.001
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7027452706774726
# Balanced accuracy score of test is  0.7037580810950403
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.42200000000000004
# threshold:0.2, J-value:0.23500000000000001
# threshold:0.30000000000000004, J-value:0.125
# threshold:0.4, J-value:0.064
# threshold:0.5, J-value:0.020999999999999998
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7110671881351893
# Balanced accuracy score of test is  0.7247043352988476
# True positive rate of class 1 is  0.682
# True positive rate of class 2 is  0.71
# Positive prediction rate of class 1 is  0.31
# Positive prediction rate of class 2 is  0.295
# X train 65694
# Y train 65694
# 21898 18970 2928
# 21898 18970 2928
# 21898 18892 3006
# 21898 18892 3006
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1315: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# 0.2586009846255978
# 0.2607431155128406
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19927
#            1       0.47      0.03      0.06      1971
#
#     accuracy                           0.91     21898
#    macro avg       0.69      0.51      0.50     21898
# weighted avg       0.87      0.91      0.87     21898
#
# Confusion_matrix
# [[19858    69]
#  [ 1911    60]]
# done in 11.364938s
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19927
#            1       0.00      0.00      0.00      1971
#
#     accuracy                           0.91     21898
#    macro avg       0.45      0.50      0.48     21898
# weighted avg       0.83      0.91      0.87     21898
#
# Confusion_matrix
# [[19927     0]
#  [ 1971     0]]
# done in 6.703871s
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19927
#            1       0.58      0.01      0.03      1971
#
#     accuracy                           0.91     21898
#    macro avg       0.75      0.51      0.49     21898
# weighted avg       0.88      0.91      0.87     21898
#
# Confusion_matrix
# [[19906    21]
#  [ 1942    29]]
# done in 79.831913s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.391
# threshold:0.2, J-value:0.252
# threshold:0.30000000000000004, J-value:0.147
# threshold:0.4, J-value:0.07100000000000001
# threshold:0.5, J-value:0.026
# threshold:0.6000000000000001, J-value:0.012
# threshold:0.7000000000000001, J-value:0.006
# threshold:0.8, J-value:0.002
# threshold:0.9, J-value:0.001
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.695381286179968
# Balanced accuracy score of test is  0.7067297156691941
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.391
# threshold:0.2, J-value:0.251
# threshold:0.30000000000000004, J-value:0.143
# threshold:0.4, J-value:0.067
# threshold:0.5, J-value:0.024
# threshold:0.6000000000000001, J-value:0.009999999999999998
# threshold:0.7000000000000001, J-value:0.005
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.695502510377408
# Balanced accuracy score of test is  0.706878617581765
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.387
# threshold:0.2, J-value:0.258
# threshold:0.30000000000000004, J-value:0.174
# threshold:0.4, J-value:0.101
# threshold:0.5, J-value:0.045
# threshold:0.6000000000000001, J-value:0.023
# threshold:0.7000000000000001, J-value:0.011
# threshold:0.8, J-value:0.007
# threshold:0.9, J-value:0.004
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6936941852640003
# Balanced accuracy score of test is  0.7060017223748666
# True positive rate of class 1 is  0.666
# True positive rate of class 2 is  0.65
# Positive prediction rate of class 1 is  0.289
# Positive prediction rate of class 2 is  0.276
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.39
# threshold:0.2, J-value:0.20600000000000002
# threshold:0.30000000000000004, J-value:0.032
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6949226144920639
# Balanced accuracy score of test is  0.7041436911902468
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.388
# threshold:0.2, J-value:0.202
# threshold:0.30000000000000004, J-value:0.030000000000000002
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6941231454960077
# Balanced accuracy score of test is  0.7028487428798247
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.39799999999999996
# threshold:0.2, J-value:0.23099999999999998
# threshold:0.30000000000000004, J-value:0.049
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6990733162365181
# Balanced accuracy score of test is  0.7124692267700974
# True positive rate of class 1 is  0.753
# True positive rate of class 2 is  0.74
# Positive prediction rate of class 1 is  0.383
# Positive prediction rate of class 2 is  0.354
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.406
# threshold:0.2, J-value:0.254
# threshold:0.30000000000000004, J-value:0.123
# threshold:0.4, J-value:0.045
# threshold:0.5, J-value:0.013000000000000001
# threshold:0.6000000000000001, J-value:0.004
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7027910841392156
# Balanced accuracy score of test is  0.7147631727443933
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.403
# threshold:0.2, J-value:0.254
# threshold:0.30000000000000004, J-value:0.122
# threshold:0.4, J-value:0.045
# threshold:0.5, J-value:0.012
# threshold:0.6000000000000001, J-value:0.003
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7013280808452175
# Balanced accuracy score of test is  0.7143417324410886
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.42500000000000004
# threshold:0.2, J-value:0.251
# threshold:0.30000000000000004, J-value:0.132
# threshold:0.4, J-value:0.05
# threshold:0.5, J-value:0.014
# threshold:0.6000000000000001, J-value:0.008
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7121369200269184
# Balanced accuracy score of test is  0.7174022036344491
# True positive rate of class 1 is  0.692
# True positive rate of class 2 is  0.693
# Positive prediction rate of class 1 is  0.302
# Positive prediction rate of class 2 is  0.298
# X train 65694
# Y train 65694
# 21898 18842 3056
# 21898 18842 3056
# 21898 18914 2984
# 21898 18914 2984
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1315: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# 0.2615435204528365
# 0.25821949119696097
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19955
#            1       0.49      0.04      0.07      1943
#
#     accuracy                           0.91     21898
#    macro avg       0.70      0.52      0.51     21898
# weighted avg       0.88      0.91      0.87     21898
#
# Confusion_matrix
# [[19881    74]
#  [ 1873    70]]
# done in 9.741886s
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19955
#            1       0.00      0.00      0.00      1943
#
#     accuracy                           0.91     21898
#    macro avg       0.46      0.50      0.48     21898
# weighted avg       0.83      0.91      0.87     21898
#
# Confusion_matrix
# [[19955     0]
#  [ 1943     0]]
# done in 6.120762s
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19955
#            1       0.51      0.01      0.03      1943
#
#     accuracy                           0.91     21898
#    macro avg       0.71      0.51      0.49     21898
# weighted avg       0.88      0.91      0.87     21898
#
# Confusion_matrix
# [[19927    28]
#  [ 1914    29]]
# done in 79.188064s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.41500000000000004
# threshold:0.2, J-value:0.26699999999999996
# threshold:0.30000000000000004, J-value:0.147
# threshold:0.4, J-value:0.07
# threshold:0.5, J-value:0.029
# threshold:0.6000000000000001, J-value:0.011
# threshold:0.7000000000000001, J-value:0.001
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7072861330045519
# Balanced accuracy score of test is  0.7038611709078313
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.41700000000000004
# threshold:0.2, J-value:0.26799999999999996
# threshold:0.30000000000000004, J-value:0.149
# threshold:0.4, J-value:0.07300000000000001
# threshold:0.5, J-value:0.028
# threshold:0.6000000000000001, J-value:0.012
# threshold:0.7000000000000001, J-value:0.002
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7082568516934857
# Balanced accuracy score of test is  0.6991896626225316
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.4
# threshold:0.2, J-value:0.26
# threshold:0.30000000000000004, J-value:0.135
# threshold:0.4, J-value:0.054000000000000006
# threshold:0.5, J-value:0.031000000000000003
# threshold:0.6000000000000001, J-value:0.007
# threshold:0.7000000000000001, J-value:-0.001
# threshold:0.8, J-value:-0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7000847571101414
# Balanced accuracy score of test is  0.7338105726872246
# True positive rate of class 1 is  0.66
# True positive rate of class 2 is  0.7
# Positive prediction rate of class 1 is  0.297
# Positive prediction rate of class 2 is  0.273
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.406
# threshold:0.2, J-value:0.21500000000000002
# threshold:0.30000000000000004, J-value:0.027
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7030417769550033
# Balanced accuracy score of test is  0.70138368457181
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.406
# threshold:0.2, J-value:0.21400000000000002
# threshold:0.30000000000000004, J-value:0.031000000000000003
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7030228117683752
# Balanced accuracy score of test is  0.6981292060458543
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.40299999999999997
# threshold:0.2, J-value:0.22100000000000003
# threshold:0.30000000000000004, J-value:0.008
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7018337352624089
# Balanced accuracy score of test is  0.7220038405060432
# True positive rate of class 1 is  0.75
# ...
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.42200000000000004
# threshold:0.2, J-value:0.284
# threshold:0.30000000000000004, J-value:0.123
# threshold:0.4, J-value:0.051
# threshold:0.5, J-value:0.015000000000000001
# threshold:0.6000000000000001, J-value:0.003
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7109427080767392
# Balanced accuracy score of test is  0.7101764288825005
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.42699999999999994
# threshold:0.2, J-value:0.293
# threshold:0.30000000000000004, J-value:0.127
# threshold:0.4, J-value:0.05
# threshold:0.5, J-value:0.016
# threshold:0.6000000000000001, J-value:0.003
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7132113697299275
# Balanced accuracy score of test is  0.7066900725452923
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.394
# threshold:0.2, J-value:0.23399999999999999
# threshold:0.30000000000000004, J-value:0.093
# threshold:0.4, J-value:0.060000000000000005
# threshold:0.5, J-value:0.012
# threshold:0.6000000000000001, J-value:0.004
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6968160997221596
# Balanced accuracy score of test is  0.7333930437378713
# True positive rate of class 1 is  0.671
# True positive rate of class 2 is  0.728
# Positive prediction rate of class 1 is  0.296
# Positive prediction rate of class 2 is  0.301
# X train 65694
# Y train 65694
# 21898 18905 2993
# 21898 18905 2993
# 21898 18918 2980
# 21898 18918 2980
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1315: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# 0.25968601816768644
# 0.25890719330005973
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19956
#            1       0.49      0.04      0.07      1942
#
#     accuracy                           0.91     21898
#    macro avg       0.70      0.52      0.51     21898
# weighted avg       0.88      0.91      0.87     21898
#
# Confusion_matrix
# [[19883    73]
#  [ 1871    71]]
# done in 11.953714s
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19956
#            1       0.00      0.00      0.00      1942
#
#     accuracy                           0.91     21898
#    macro avg       0.46      0.50      0.48     21898
# weighted avg       0.83      0.91      0.87     21898
#
# Confusion_matrix
# [[19956     0]
#  [ 1942     0]]
# done in 6.683143s
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19956
#            1       0.53      0.02      0.03      1942
#
#     accuracy                           0.91     21898
#    macro avg       0.72      0.51      0.49     21898
# weighted avg       0.88      0.91      0.87     21898
#
# Confusion_matrix
# [[19927    29]
#  [ 1909    33]]
# done in 76.375250s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.391
# threshold:0.2, J-value:0.253
# threshold:0.30000000000000004, J-value:0.147
# threshold:0.4, J-value:0.07100000000000001
# threshold:0.5, J-value:0.037000000000000005
# threshold:0.6000000000000001, J-value:0.008
# threshold:0.7000000000000001, J-value:0.003
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6957983436348029
# Balanced accuracy score of test is  0.6988687419222392
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.389
# threshold:0.2, J-value:0.24800000000000003
# threshold:0.30000000000000004, J-value:0.149
# threshold:0.4, J-value:0.07300000000000001
# threshold:0.5, J-value:0.036000000000000004
# threshold:0.6000000000000001, J-value:0.008
# threshold:0.7000000000000001, J-value:0.002
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6948425891746475
# Balanced accuracy score of test is  0.6977093090894304
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.404
# threshold:0.2, J-value:0.285
# threshold:0.30000000000000004, J-value:0.129
# threshold:0.4, J-value:0.066
# threshold:0.5, J-value:0.038
# threshold:0.6000000000000001, J-value:0.009999999999999998
# threshold:0.7000000000000001, J-value:0.006
# threshold:0.8, J-value:-0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7023452006455311
# Balanced accuracy score of test is  0.705972297175751
# True positive rate of class 1 is  0.655
# True positive rate of class 2 is  0.643
# Positive prediction rate of class 1 is  0.295
# Positive prediction rate of class 2 is  0.266
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.38099999999999995
# threshold:0.2, J-value:0.20900000000000002
# threshold:0.30000000000000004, J-value:0.041
# threshold:0.4, J-value:0.001
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6902551219092754
# Balanced accuracy score of test is  0.6993108319249827
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.375
# threshold:0.2, J-value:0.20900000000000002
# threshold:0.30000000000000004, J-value:0.042
# threshold:0.4, J-value:0.001
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.6874474232868594
# Balanced accuracy score of test is  0.6981059900964945
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.416
# threshold:0.2, J-value:0.21399999999999997
# threshold:0.30000000000000004, J-value:0.028999999999999998
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7083257396269971
# Balanced accuracy score of test is  0.70659830904839
# True positive rate of class 1 is  0.743
# True positive rate of class 2 is  0.725
# Positive prediction rate of class 1 is  0.382
# Positive prediction rate of class 2 is  0.348
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.40700000000000003
# threshold:0.2, J-value:0.26299999999999996
# threshold:0.30000000000000004, J-value:0.135
# threshold:0.4, J-value:0.048
# threshold:0.5, J-value:0.016
# threshold:0.6000000000000001, J-value:0.001
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7038283986208953
# Balanced accuracy score of test is  0.7132662248295374
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.404
# threshold:0.2, J-value:0.26499999999999996
# threshold:0.30000000000000004, J-value:0.138
# threshold:0.4, J-value:0.047
# threshold:0.5, J-value:0.015000000000000001
# threshold:0.6000000000000001, J-value:0.001
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7018352232046635
# Balanced accuracy score of test is  0.7129843143640047
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.43199999999999994
# threshold:0.2, J-value:0.249
# threshold:0.30000000000000004, J-value:0.11300000000000002
# threshold:0.4, J-value:0.048
# threshold:0.5, J-value:0.022000000000000002
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7162304577618244
# Balanced accuracy score of test is  0.7147544522396114
# True positive rate of class 1 is  0.698
# True positive rate of class 2 is  0.682
# Positive prediction rate of class 1 is  0.31
# Positive prediction rate of class 2 is  0.29
# X train 65694
# Y train 65694
# 21898 18847 3051
# 21898 18847 3051
# 21898 18817 3081
# 21898 18817 3081
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1315: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn("l1_ratio parameter is only used when penalty is "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "
# 0.2599848812794757
# 0.2649508533895226
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19866
#            1       0.45      0.03      0.06      2032
#
#     accuracy                           0.91     21898
#    macro avg       0.68      0.51      0.51     21898
# weighted avg       0.87      0.91      0.87     21898
#
# Confusion_matrix
# [[19784    82]
#  [ 1966    66]]
# done in 9.728797s
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19866
#            1       0.00      0.00      0.00      2032
#
#     accuracy                           0.91     21898
#    macro avg       0.45      0.50      0.48     21898
# weighted avg       0.82      0.91      0.86     21898
#
# Confusion_matrix
# [[19866     0]
#  [ 2032     0]]
# done in 6.106532s
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95     19866
#            1       0.55      0.02      0.03      2032
#
#     accuracy                           0.91     21898
#    macro avg       0.73      0.51      0.49     21898
# weighted avg       0.88      0.91      0.87     21898
#
# Confusion_matrix
# [[19841    25]
#  [ 2001    31]]
# done in 79.536740s
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.40700000000000003
# threshold:0.2, J-value:0.26
# threshold:0.30000000000000004, J-value:0.153
# threshold:0.4, J-value:0.07300000000000001
# threshold:0.5, J-value:0.032
# threshold:0.6000000000000001, J-value:0.009999999999999998
# threshold:0.7000000000000001, J-value:0.004
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7034212550579646
# Balanced accuracy score of test is  0.7069820801337465
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.403
# threshold:0.2, J-value:0.261
# threshold:0.30000000000000004, J-value:0.151
# threshold:0.4, J-value:0.07100000000000001
# threshold:0.5, J-value:0.030000000000000002
# threshold:0.6000000000000001, J-value:0.011
# threshold:0.7000000000000001, J-value:0.004
# threshold:0.8, J-value:0.001
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7015040547223479
# Balanced accuracy score of test is  0.7070228762273059
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.43
# threshold:0.2, J-value:0.25
# threshold:0.30000000000000004, J-value:0.171
# threshold:0.4, J-value:0.084
# threshold:0.5, J-value:0.046
# threshold:0.6000000000000001, J-value:0.006
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7151862973007879
# Balanced accuracy score of test is  0.7065688353743358
# True positive rate of class 1 is  0.671
# True positive rate of class 2 is  0.649
# Positive prediction rate of class 1 is  0.295
# Positive prediction rate of class 2 is  0.274
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.40399999999999997
# threshold:0.2, J-value:0.197
# threshold:0.30000000000000004, J-value:0.039
# threshold:0.4, J-value:0.001
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.701836947411473
# Balanced accuracy score of test is  0.7001265020915726
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.40299999999999997
# threshold:0.2, J-value:0.198
# threshold:0.30000000000000004, J-value:0.039
# threshold:0.4, J-value:0.001
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7017063399524524
# Balanced accuracy score of test is  0.6963671580075166
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.40499999999999997
# threshold:0.2, J-value:0.193
# threshold:0.30000000000000004, J-value:0.036
# threshold:0.4, J-value:0.0
# threshold:0.5, J-value:0.0
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7025075067803177
# Balanced accuracy score of test is  0.7231667084749113
# True positive rate of class 1 is  0.733
# True positive rate of class 2 is  0.748
# Positive prediction rate of class 1 is  0.376
# Positive prediction rate of class 2 is  0.343
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.42799999999999994
# threshold:0.2, J-value:0.261
# threshold:0.30000000000000004, J-value:0.132
# threshold:0.4, J-value:0.039
# threshold:0.5, J-value:0.011
# threshold:0.6000000000000001, J-value:0.002
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7138643402359419
# Balanced accuracy score of test is  0.712570828884233
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.42699999999999994
# threshold:0.2, J-value:0.261
# threshold:0.30000000000000004, J-value:0.135
# threshold:0.4, J-value:0.04
# threshold:0.5, J-value:0.011
# threshold:0.6000000000000001, J-value:0.002
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.7133643377700877
# Balanced accuracy score of test is  0.7137129966769622
# threshold:0.0, J-value:0.0
# threshold:0.1, J-value:0.43400000000000005
# threshold:0.2, J-value:0.259
# threshold:0.30000000000000004, J-value:0.11100000000000002
# threshold:0.4, J-value:0.037000000000000005
# threshold:0.5, J-value:0.011
# threshold:0.6000000000000001, J-value:0.0
# threshold:0.7000000000000001, J-value:0.0
# threshold:0.8, J-value:0.0
# threshold:0.9, J-value:0.0
# Optimal threshold by J value is  0.1
# Balanced accuracy score of val is  0.71687734082397
# Balanced accuracy score of test is  0.7054172082734715
# True positive rate of class 1 is  0.695
# True positive rate of class 2 is  0.67
# Positive prediction rate of class 1 is  0.308
# Positive prediction rate of class 2 is  0.297

# %%
def add_mean_sd(records, result_table, overall_records, type):
    records.append({
        'auroc': result_table["auroc"].mean(),
        'overall threshold': result_table["overall threshold"].mean(),
        'white threshold': result_table["white threshold"].mean(),
        'black threshold': result_table["black threshold"].mean(),
        'overall ba validation': result_table["overall ba validation"].mean(),
        'overall ba test': result_table["overall ba test"].mean(),
        'white ba validation': result_table["white ba validation"].mean(),
        'white ba test': result_table["white ba test"].mean(),
        'black ba validation': result_table["black ba validation"].mean(),
        'black ba test': result_table["black ba test"].mean(),
        'overall precision':result_table["overall precision"].mean(),
        'overall recall':result_table["overall recall"].mean(),
        'overall tpr':result_table["overall tpr"].mean(),
        'overall tnr':result_table["overall tnr"].mean(),
        'overall pd':result_table["overall pd"].mean(),
        'white precision':result_table["white precision"].mean(),
        'white recall':result_table["white recall"].mean(),
        'white tpr':result_table["white tpr"].mean(),
        'white tnr':result_table["white tnr"].mean(),
        'white pd':result_table["white pd"].mean(),
        'black precision':result_table["black precision"].mean(),
        'black recall':result_table["black recall"].mean(),
        'black tpr':result_table["black tpr"].mean(),
        'black tnr':result_table["black tnr"].mean(),
        'black pd':result_table["black pd"].mean(),
        'eod': result_table["eod"].mean(),
        'di': result_table["di"].mean(),
        })
    records.append({
        'auroc': result_table["auroc"].std(),
        'overall threshold': result_table["overall threshold"].std(),
        'white threshold': result_table["white threshold"].std(),
        'black threshold': result_table["black threshold"].std(),
        'overall ba validation': result_table["overall ba validation"].std(),
        'overall ba test': result_table["overall ba test"].std(),
        'white ba validation': result_table["white ba validation"].std(),
        'white ba test': result_table["white ba test"].std(),
        'black ba validation': result_table["black ba validation"].std(),
        'black ba test': result_table["black ba test"].std(),
        'overall precision':result_table["overall precision"].std(),
        'overall recall':result_table["overall recall"].std(),
        'overall tpr':result_table["overall tpr"].std(),
        'overall tnr':result_table["overall tnr"].std(),
        'overall pd':result_table["overall pd"].std(),
        'white precision':result_table["white precision"].std(),
        'white recall':result_table["white recall"].std(),
        'white tpr':result_table["white tpr"].std(),
        'white tnr':result_table["white tnr"].std(),
        'white pd':result_table["white pd"].std(),
        'black precision':result_table["black precision"].std(),
        'black recall':result_table["black recall"].std(),
        'black tpr':result_table["black tpr"].std(),
        'black tnr':result_table["black tnr"].std(),
        'black pd':result_table["black pd"].std(),
        'eod': result_table["eod"].std(),
        'di': result_table["di"].std(),
        })
    overall_records.append({
        'type': type,
        'auroc': result_table["auroc"].mean(),
        'auroc_std': result_table["auroc"].std(),
        'overall threshold': result_table["overall threshold"].mean(),
        'white threshold': result_table["white threshold"].mean(),
        'black threshold': result_table["black threshold"].mean(),
        'overall ba test': result_table["overall ba test"].mean(),
        'ba_std': result_table["overall ba test"].std(),
        'white ba test': result_table["white ba test"].mean(),
        'black ba test': result_table["black ba test"].mean(),
        'overall tpr':result_table["overall tpr"].mean(),
        'overall pd':result_table["overall pd"].mean(),
        'white tpr':result_table["white tpr"].mean(),
        'white pd':result_table["white pd"].mean(),
        'black tpr':result_table["black tpr"].mean(),
        'black pd':result_table["black pd"].mean(),
        'eod': result_table["eod"].mean(),
        'eod_std': result_table["eod"].std(),
        'di': result_table["di"].mean(),
        'di_std': result_table["di"].std()
        })
    pd_result = pd.DataFrame(records)
    return pd_result, overall_records

# %%
overall_table = []
result_lr, overall_records = add_mean_sd (records_lr, result_lr, overall_table, 'lr')
result_rf, overall_records = add_mean_sd (records_rf, result_rf, overall_records, 'rf')
#result_dt, overall_records = add_mean_sd (records_dt, result_dt, overall_records, 'dt')
result_gbt, overall_records = add_mean_sd (records_gbt, result_gbt, overall_records, 'gbt')

result_path='/Users/lifuchen/Desktop/research/resample_data/'
result_lr.to_csv(path.join(result_path,'race-lr-result_no_protected.csv'), index=False)
result_rf.to_csv(path.join(result_path,'race-rf-result_no_protected.csv'), index=False)
#result_dt.to_csv(path.join(result_path,'race-dt-result_no_protected.csv'), index=False)
result_gbt.to_csv(path.join(result_path,'race-gbt-result_no_protected.csv'), index=False)

overall_result = pd.DataFrame(overall_table)
result_path='/Users/lifuchen/Desktop/research/resample_result/'
overall_result.to_csv(path.join(result_path,'race_no_protected.csv'), index=False)
